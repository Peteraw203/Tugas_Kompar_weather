# %% [markdown]
# # Kelompok:
# #### Peter Abednego Wijaya 			235150300111013
# #### Gilang Shido Faizalhaq			235150300111011
# #### Rizqy Jauhary Atsaany			235150300111038

# %% [markdown]
# ## Pastikan install library terlebih dahulu. Run di terminal:
# ### pip install pandas requests openpyxl

# %% [markdown]
# ## Langkah 1, cek data-data yang disediakan pada weather API

# %%
import requests
import json # Menggunakan json

# --- KONFIGURASI ---
# API key
API_KEY = "242819b7dfe84b4488a34756251809" 
LOKASI_CONTOH = "Malang" # Coba ambil data untuk Malang
# --- AKHIR KONFIGURASI --

# URL endpoint dari WeatherAPI
url = f"http://api.weatherapi.com/v1/current.json?key={API_KEY}&q={LOKASI_CONTOH}&aqi=no"

print(f"Mengambil data cuaca untuk: {LOKASI_CONTOH}...")

try:
    response = requests.get(url, timeout=10)
    response.raise_for_status()  # Error jika status code bukan 2xx
    
    data = response.json()
    
    # Cetak seluruh response JSON dengan format yang rapi
    print("\n--- Struktur Data JSON Lengkap ---")
    print(json.dumps(data, indent=4))
    
except requests.exceptions.RequestException as e:
    print(f"Gagal mendapatkan data: {e}")
# Out:
# Mengambil data cuaca untuk: Malang...
#
# --- Struktur Data JSON Lengkap ---
# {
#     "location": {
#         "name": "Malang",
#         "region": "East Java",
#         "country": "Indonesia",
#         "lat": -7.9797,
#         "lon": 112.6304,
#         "tz_id": "Asia/Jakarta",
#         "localtime_epoch": 1758772256,
#         "localtime": "2025-09-25 10:50"
#     },
#     "current": {
#         "last_updated_epoch": 1758771900,
#         "last_updated": "2025-09-25 10:45",
#         "temp_c": 32.3,
#         "temp_f": 90.1,
#         "is_day": 1,
#         "condition": {
#             "text": "Patchy rain nearby",
#             "icon": "//cdn.weatherapi.com/weather/64x64/day/176.png",
#             "code": 1063
#         },
#         "wind_mph": 2.2,
#         "wind_kph": 3.6,
#         "wind_degree": 285,
#         "wind_dir": "WNW",
#         "pressure_mb": 1010.0,
#         "pressure_in": 29.83,
#         "precip_mm": 0.01,
#         "precip_in": 0.0,
#         "humidity": 63,
#         "cloud": 25,
#         "feelslike_c": 36.1,
#         "feelslike_f": 97.0,
#         "windchill_c": 28.9,
#         "windchill_f": 84.0,
#         "heatindex_c": 30.2,
#         "heatindex_f": 86.4,
#         "dewpoint_c": 18.3,
#         "dewpoint_f": 64.9,
#         "vis_km": 10.0,
#         "vis_miles": 6.0,
#         "uv": 11.6,
#         "gust_mph": 6.7,
#         "gust_kph": 10.8,
#         "short_rad": 687.1,
#         "diff_rad": 103.6,
#         "dni": 0.0,
#         "gti": 103.76
#     }
# }

# %% [markdown]
# # 2. Membuat file excel bernama "DaftarKecamatan" dan pada kolom pertama di isi kecamatan-kecamatan di Jawa Timur

# %% [markdown]
# # 3. Membuat script untuk membaca file Excel, mengambil data cuaca untuk setiap kecamatan menggunakan multi-threading, dan menuliskannya kembali ke file Excel yang sama.

# %%
# --- 1. IMPORT LIBRARY YANG DIBUTUHKAN ---
import pandas as pd
import requests
import threading
from datetime import datetime

# --- 2. KONFIGURASI UTAMA ---
API_KEY = "242819b7dfe84b4488a34756251809"
NAMA_FILE_EXCEL = "DaftarKecamatan_kelompok_6.xlsx"
NAMA_KOLOM_KECAMATAN = "Kecamatan"

# =========== BAGIAN UNTUK METODE MULTI-THREADING =============

# --- 3A. PERSIAPAN UNTUK MULTI-THREADING ---
results = []
lock = threading.Lock()

# --- 4A. FUNGSI GET DATA (UNTUK THREAD) ---
def get_weather_data_threaded(kecamatan, index):
    """Fungsi ini dijalankan oleh setiap thread. Hasilnya disimpan di list global 'results'."""
    url = f"http://api.weatherapi.com/v1/current.json?key={API_KEY}&q={kecamatan}&aqi=no"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        weather_info = {
            'Last Update': data['location']['localtime'],
            'Suhu (°C)': data['current']['temp_c'],
            'Kelembapan (%)': data['current']['humidity'],
            'Kondisi Cuaca': data['current']['condition']['text'],
            'Kecepatan Angin (km/h)': data['current']['wind_kph'],
            'Arah Angin': data['current']['wind_dir'],
            'Sinar UV': data['current']['uv']
        }
        print(f"✅ [Thread] Berhasil -> {kecamatan}")
    except requests.exceptions.RequestException:
        print(f"❌ [Thread] Gagal    -> {kecamatan}")
        weather_info = {
            'Last Update': 'Error', 'Suhu (°C)': 'Error', 'Kelembapan (%)': 'Error',
            'Kondisi Cuaca': 'Error', 'Kecepatan Angin (km/h)': 'Error',
            'Arah Angin' : 'Error', 'Sinar UV': 'Error'
        }
    with lock:
        results.append({'index': index, 'data': weather_info})

# --- 5A. FUNGSI UTAMA (MULTI-THREAD) ---
def run_w_multithread():
    start_time = datetime.now()
    df = pd.read_excel(NAMA_FILE_EXCEL, engine='openpyxl')
    threads = []
    
    # Kosongkan list results setiap kali fungsi dijalankan
    results.clear()
    
    print(f"🚀 Memulai pengambilan data untuk {len(df)} kecamatan (Multi-Thread)...")
    for index, row in df.iterrows():
        kecamatan = row[NAMA_KOLOM_KECAMATAN]
        if pd.notna(kecamatan):
            thread = threading.Thread(target=get_weather_data_threaded, args=(kecamatan, index))
            threads.append(thread)
            thread.start()

    for thread in threads:
        thread.join()

    print("\nSemua thread selesai. Menulis data ke Excel...")
    for result in results:
        idx = result['index']
        for key, value in result['data'].items():
            df.loc[idx, key] = value
            
    df.to_excel(NAMA_FILE_EXCEL, index=False)
    end_time = datetime.now()
    print(f"\n✅ Selesai! Data cuaca telah ditulis ke '{NAMA_FILE_EXCEL}'.")
    print(f"Total waktu eksekusi (Multi-Thread): {end_time - start_time}")

# =========== BAGIAN UNTUK METODE SEQUENTIAL ============

# --- 4B. FUNGSI GET DATA (UNTUK SEQUENTIAL) ---
def get_weather_data_sequential(kecamatan):
    """Fungsi ini dijalankan satu per satu. Hasilnya langsung di-'return'."""
    url = f"http://api.weatherapi.com/v1/current.json?key={API_KEY}&q={kecamatan}&aqi=no"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        weather_info = {
            'Last Update': data['location']['localtime'],
            'Suhu (°C)': data['current']['temp_c'],
            'Kelembapan (%)': data['current']['humidity'],
            'Kondisi Cuaca': data['current']['condition']['text'],
            'Kecepatan Angin (km/h)': data['current']['wind_kph'],
            'Arah Angin': data['current']['wind_dir'],
            'Sinar UV': data['current']['uv']
        }
        print(f"✅ [Seq] Berhasil -> {kecamatan}")
    except requests.exceptions.RequestException:
        print(f"❌ [Seq] Gagal    -> {kecamatan}")
        weather_info = {
            'Last Update': 'Error', 'Suhu (°C)': 'Error', 'Kelembapan (%)': 'Error',
            'Kondisi Cuaca': 'Error', 'Kecepatan Angin (km/h)': 'Error', 
            'Arah Angin' : 'Error', 'Sinar UV': 'Error'
        }
    return weather_info

# --- 5B. FUNGSI UTAMA (SEQUENTIAL) ---
def run_sequentially():
    start_time = datetime.now()
    df = pd.read_excel(NAMA_FILE_EXCEL, engine='openpyxl')
    
    print(f"🐢 Memulai pengambilan data untuk {len(df)} kecamatan (Sekuensial)...")
    for index, row in df.iterrows():
        kecamatan = row[NAMA_KOLOM_KECAMATAN]
        if pd.notna(kecamatan):
            weather_data = get_weather_data_sequential(kecamatan)
            for key, value in weather_data.items():
                df.loc[index, key] = value
            
    print("\nSemua data telah diambil. Menulis data ke Excel...")
    df.to_excel(NAMA_FILE_EXCEL, index=False)
    end_time = datetime.now()
    print(f"\n✅ Selesai! Data cuaca telah ditulis ke '{NAMA_FILE_EXCEL}'.")
    print(f"Total waktu eksekusi (Sekuensial): {end_time - start_time}")


# ======================== PANEL KONTROL EKSEKUSI ===========================
if __name__ == "__main__":
    # --- Pilihan 1: Mode Cepat (Multi-Thread) ---
    # run_w_multithread()
    
    # --- Pilihan 2: Mode Sabar (Sekuensial) ---
    run_sequentially()
# Out:
# 🐢 Memulai pengambilan data untuk 591 kecamatan (Sekuensial)...
# ✅ [Seq] Berhasil -> Asemrowo, Surabaya
# ✅ [Seq] Berhasil -> Benowo, Surabaya
# ✅ [Seq] Berhasil -> Bubutan, Surabaya
# ✅ [Seq] Berhasil -> Bulak, Surabaya
# ✅ [Seq] Berhasil -> Dukuh Pakis, Surabaya
# ✅ [Seq] Berhasil -> Gayungan, Surabaya
# ✅ [Seq] Berhasil -> Genteng, Surabaya
# ✅ [Seq] Berhasil -> Gubeng, Surabaya
# ✅ [Seq] Berhasil -> Gunung Anyar, Surabaya
# ✅ [Seq] Berhasil -> Jambangan, Surabaya
# ✅ [Seq] Berhasil -> Karang Pilang, Surabaya
# ✅ [Seq] Berhasil -> Kenjeran, Surabaya
# ✅ [Seq] Berhasil -> Krembangan, Surabaya
# ✅ [Seq] Berhasil -> Lakarsantri, Surabaya
# ✅ [Seq] Berhasil -> Mulyorejo, Surabaya
# ✅ [Seq] Berhasil -> Pabean Cantian, Surabaya
# ✅ [Seq] Berhasil -> Pakal, Surabaya
# ✅ [Seq] Berhasil -> Rungkut, Surabaya
# ✅ [Seq] Berhasil -> Sambikerep, Surabaya
# ✅ [Seq] Berhasil -> Sawahan, Surabaya
# ✅ [Seq] Berhasil -> Semampir, Surabaya
# ✅ [Seq] Berhasil -> Simokerto, Surabaya
# ✅ [Seq] Berhasil -> Sukolilo, Surabaya
# ✅ [Seq] Berhasil -> Suko Manunggal, Surabaya
# ✅ [Seq] Berhasil -> Tambaksari, Surabaya
# ✅ [Seq] Berhasil -> Tandes, Surabaya
# ✅ [Seq] Berhasil -> Tegalsari, Surabaya
# ✅ [Seq] Berhasil -> Tenggilis Mejoyo, Surabaya
# ✅ [Seq] Berhasil -> Wiyung, Surabaya
# ✅ [Seq] Berhasil -> Wonocolo, Surabaya
# ✅ [Seq] Berhasil -> Wonokromo, Surabaya
# ✅ [Seq] Berhasil -> Balongbendo, Sidoarjo
# ✅ [Seq] Berhasil -> Buduran, Sidoarjo
# ✅ [Seq] Berhasil -> Candi, Sidoarjo
# ✅ [Seq] Berhasil -> Gedangan, Sidoarjo
# ✅ [Seq] Berhasil -> Jabon, Sidoarjo
# ✅ [Seq] Berhasil -> Krembung, Sidoarjo
# ✅ [Seq] Berhasil -> Krian, Sidoarjo
# ✅ [Seq] Berhasil -> Prambon, Sidoarjo
# ✅ [Seq] Berhasil -> Porong, Sidoarjo
# ✅ [Seq] Berhasil -> Sedati, Sidoarjo
# ✅ [Seq] Berhasil -> Sidoarjo, Sidoarjo
# ✅ [Seq] Berhasil -> Sukodono, Sidoarjo
# ✅ [Seq] Berhasil -> Taman, Sidoarjo
# ✅ [Seq] Berhasil -> Tanggulangin, Sidoarjo
# ✅ [Seq] Berhasil -> Tarik, Sidoarjo
# ✅ [Seq] Berhasil -> Tulangan, Sidoarjo
# ✅ [Seq] Berhasil -> Waru, Sidoarjo
# ✅ [Seq] Berhasil -> Wonoayu, Sidoarjo
# ✅ [Seq] Berhasil -> Balong, Ponorogo
# ✅ [Seq] Berhasil -> Babadan, Ponorogo
# ✅ [Seq] Berhasil -> Badegan, Ponorogo
# ✅ [Seq] Berhasil -> Bungkal, Ponorogo
# ✅ [Seq] Berhasil -> Jambon, Ponorogo
# ✅ [Seq] Berhasil -> Jenangan, Ponorogo
# ✅ [Seq] Berhasil -> Jetis, Ponorogo
# ✅ [Seq] Berhasil -> Kauman, Ponorogo
# ✅ [Seq] Berhasil -> Mlarak, Ponorogo
# ✅ [Seq] Berhasil -> Ngebel, Ponorogo
# ✅ [Seq] Berhasil -> Ngrayun, Ponorogo
# ✅ [Seq] Berhasil -> Ponorogo, Ponorogo
# ✅ [Seq] Berhasil -> Pudak, Ponorogo
# ✅ [Seq] Berhasil -> Pulung, Ponorogo
# ✅ [Seq] Berhasil -> Sambit, Ponorogo
# ✅ [Seq] Berhasil -> Sampung, Ponorogo
# ✅ [Seq] Berhasil -> Sawoo, Ponorogo
# ✅ [Seq] Berhasil -> Siman, Ponorogo
# ✅ [Seq] Berhasil -> Slahung, Ponorogo
# ✅ [Seq] Berhasil -> Sooko, Ponorogo
# ✅ [Seq] Berhasil -> Sukorejo, Ponorogo
# ✅ [Seq] Berhasil -> Arjosari, Pacitan
# ✅ [Seq] Berhasil -> Bandar, Pacitan
# ✅ [Seq] Berhasil -> Donorojo, Pacitan
# ✅ [Seq] Berhasil -> Kebonagung, Pacitan
# ✅ [Seq] Berhasil -> Nawangan, Pacitan
# ✅ [Seq] Berhasil -> Ngadirojo, Pacitan
# ✅ [Seq] Berhasil -> Pacitan, Pacitan
# ✅ [Seq] Berhasil -> Pringkuku, Pacitan
# ✅ [Seq] Berhasil -> Punung, Pacitan
# ✅ [Seq] Berhasil -> Sudimoro, Pacitan
# ✅ [Seq] Berhasil -> Tegalombo, Pacitan
# ✅ [Seq] Berhasil -> Tulakan, Pacitan
# ✅ [Seq] Berhasil -> Bendungan, Trenggalek
# ✅ [Seq] Berhasil -> Dongko, Trenggalek
# ✅ [Seq] Berhasil -> Durenan, Trenggalek
# ✅ [Seq] Berhasil -> Gandusari, Trenggalek
# ✅ [Seq] Berhasil -> Kampak, Trenggalek
# ✅ [Seq] Berhasil -> Karangan, Trenggalek
# ✅ [Seq] Berhasil -> Munjungan, Trenggalek
# ✅ [Seq] Berhasil -> Panggul, Trenggalek
# ✅ [Seq] Berhasil -> Pogalan, Trenggalek
# ✅ [Seq] Berhasil -> Pule, Trenggalek
# ✅ [Seq] Berhasil -> Suruh, Trenggalek
# ✅ [Seq] Berhasil -> Trenggalek, Trenggalek
# ✅ [Seq] Berhasil -> Tugu, Trenggalek
# ✅ [Seq] Berhasil -> Watulimo, Trenggalek
# ✅ [Seq] Berhasil -> Bandung, Tulungagung
# ✅ [Seq] Berhasil -> Besuki, Tulungagung
# ✅ [Seq] Berhasil -> Boyolangu, Tulungagung
# ✅ [Seq] Berhasil -> Campurdarat, Tulungagung
# ✅ [Seq] Berhasil -> Gondang, Tulungagung
# ✅ [Seq] Berhasil -> Kalidawir, Tulungagung
# ✅ [Seq] Berhasil -> Karangrejo, Tulungagung
# ✅ [Seq] Berhasil -> Kauman, Tulungagung
# ✅ [Seq] Berhasil -> Kedungwaru, Tulungagung
# ✅ [Seq] Berhasil -> Ngantru, Tulungagung
# ✅ [Seq] Berhasil -> Ngunut, Tulungagung
# ✅ [Seq] Berhasil -> Pagerwojo, Tulungagung
# ✅ [Seq] Berhasil -> Pakel, Tulungagung
# ✅ [Seq] Berhasil -> Pucanglaban, Tulungagung
# ✅ [Seq] Berhasil -> Rejotangan, Tulungagung
# ✅ [Seq] Berhasil -> Sendang, Tulungagung
# ✅ [Seq] Berhasil -> Sumbergempol, Tulungagung
# ✅ [Seq] Berhasil -> Tanggunggunung, Tulungagung
# ✅ [Seq] Berhasil -> Tulungagung, Tulungagung
# ✅ [Seq] Berhasil -> Bakung, Blitar
# ✅ [Seq] Berhasil -> Binangun, Blitar
# ✅ [Seq] Berhasil -> Doko, Blitar
# ✅ [Seq] Berhasil -> Gandusari, Blitar
# ✅ [Seq] Berhasil -> Garum, Blitar
# ✅ [Seq] Berhasil -> Kademangan, Blitar
# ✅ [Seq] Berhasil -> Kanigoro, Blitar
# ✅ [Seq] Berhasil -> Kesamben, Blitar
# ✅ [Seq] Berhasil -> Nglegok, Blitar
# ✅ [Seq] Berhasil -> Panggungrejo, Blitar
# ✅ [Seq] Berhasil -> Ponggok, Blitar
# ✅ [Seq] Berhasil -> Sananankulon, Blitar
# ✅ [Seq] Berhasil -> Selopuro, Blitar
# ✅ [Seq] Berhasil -> Selorejo, Blitar
# ✅ [Seq] Berhasil -> Srengat, Blitar
# ✅ [Seq] Berhasil -> Sutojayan, Blitar
# ✅ [Seq] Berhasil -> Talun, Blitar
# ✅ [Seq] Berhasil -> Udanawu, Blitar
# ✅ [Seq] Berhasil -> Wates, Blitar
# ✅ [Seq] Berhasil -> Wlingi, Blitar
# ✅ [Seq] Berhasil -> Wonodadi, Blitar
# ✅ [Seq] Berhasil -> Wonotirto, Blitar
# ✅ [Seq] Berhasil -> Badas, Kediri
# ✅ [Seq] Berhasil -> Banyakan, Kediri
# ✅ [Seq] Berhasil -> Gampengrejo, Kediri
# ✅ [Seq] Berhasil -> Grogol, Kediri
# ✅ [Seq] Berhasil -> Gurah, Kediri
# ✅ [Seq] Berhasil -> Kandangan, Kediri
# ✅ [Seq] Berhasil -> Kandat, Kediri
# ✅ [Seq] Berhasil -> Kayen Kidul, Kediri
# ✅ [Seq] Berhasil -> Kepung, Kediri
# ✅ [Seq] Berhasil -> Kras, Kediri
# ✅ [Seq] Berhasil -> Kunjang, Kediri
# ✅ [Seq] Berhasil -> Mojo, Kediri
# ✅ [Seq] Berhasil -> Ngadiluwih, Kediri
# ✅ [Seq] Berhasil -> Ngancar, Kediri
# ✅ [Seq] Berhasil -> Ngasem, Kediri
# ✅ [Seq] Berhasil -> Pagu, Kediri
# ✅ [Seq] Berhasil -> Papar, Kediri
# ✅ [Seq] Berhasil -> Pare, Kediri
# ✅ [Seq] Berhasil -> Plemahan, Kediri
# ✅ [Seq] Berhasil -> Plosoklaten, Kediri
# ✅ [Seq] Berhasil -> Puncu, Kediri
# ✅ [Seq] Berhasil -> Purwoasri, Kediri
# ✅ [Seq] Berhasil -> Ringinrejo, Kediri
# ✅ [Seq] Berhasil -> Semen, Kediri
# ✅ [Seq] Berhasil -> Tarokan, Kediri
# ✅ [Seq] Berhasil -> Wates, Kediri
# ✅ [Seq] Berhasil -> Ampelgading, Malang
# ✅ [Seq] Berhasil -> Bantur, Malang
# ✅ [Seq] Berhasil -> Bululawang, Malang
# ✅ [Seq] Berhasil -> Dampit, Malang
# ✅ [Seq] Berhasil -> Dau, Malang
# ✅ [Seq] Berhasil -> Donomulyo, Malang
# ✅ [Seq] Berhasil -> Gedangan, Malang
# ✅ [Seq] Berhasil -> Gondanglegi, Malang
# ✅ [Seq] Berhasil -> Jabung, Malang
# ✅ [Seq] Berhasil -> Kalipare, Malang
# ✅ [Seq] Berhasil -> Karangploso, Malang
# ✅ [Seq] Berhasil -> Kasembon, Malang
# ✅ [Seq] Berhasil -> Kepanjen, Malang
# ✅ [Seq] Berhasil -> Kromengan, Malang
# ✅ [Seq] Berhasil -> Lawang, Malang
# ✅ [Seq] Berhasil -> Ngajum, Malang
# ✅ [Seq] Berhasil -> Ngantang, Malang
# ✅ [Seq] Berhasil -> Pagak, Malang
# ✅ [Seq] Berhasil -> Pagelaran, Malang
# ✅ [Seq] Berhasil -> Pakis, Malang
# ✅ [Seq] Berhasil -> Pakisaji, Malang
# ✅ [Seq] Berhasil -> Poncokusumo, Malang
# ✅ [Seq] Berhasil -> Pujon, Malang
# ✅ [Seq] Berhasil -> Singosari, Malang
# ✅ [Seq] Berhasil -> Sumbermanjing Wetan, Malang
# ✅ [Seq] Berhasil -> Sumberpucung, Malang
# ✅ [Seq] Berhasil -> Tajinan, Malang
# ✅ [Seq] Berhasil -> Tirtoyudo, Malang
# ✅ [Seq] Berhasil -> Tumpang, Malang
# ✅ [Seq] Berhasil -> Turen, Malang
# ✅ [Seq] Berhasil -> Wagir, Malang
# ✅ [Seq] Berhasil -> Wajak, Malang
# ✅ [Seq] Berhasil -> Wonosari, Malang
# ✅ [Seq] Berhasil -> Ambulu, Jember
# ✅ [Seq] Berhasil -> Ajung, Jember
# ✅ [Seq] Berhasil -> Arjasa, Jember
# ✅ [Seq] Berhasil -> Balung, Jember
# ✅ [Seq] Berhasil -> Bangsalsari, Jember
# ✅ [Seq] Berhasil -> Gumukmas, Jember
# ✅ [Seq] Berhasil -> Jelbuk, Jember
# ✅ [Seq] Berhasil -> Jenggawah, Jember
# ✅ [Seq] Berhasil -> Jombang, Jember
# ✅ [Seq] Berhasil -> Kalisat, Jember
# ✅ [Seq] Berhasil -> Kaliwates, Jember
# ✅ [Seq] Berhasil -> Kencong, Jember
# ✅ [Seq] Berhasil -> Ledokombo, Jember
# ✅ [Seq] Berhasil -> Mayang, Jember
# ✅ [Seq] Berhasil -> Mumbulsari, Jember
# ✅ [Seq] Berhasil -> Panti, Jember
# ✅ [Seq] Berhasil -> Pakusari, Jember
# ✅ [Seq] Berhasil -> Patrang, Jember
# ✅ [Seq] Berhasil -> Puger, Jember
# ✅ [Seq] Berhasil -> Rambipuji, Jember
# ✅ [Seq] Berhasil -> Semboro, Jember
# ✅ [Seq] Berhasil -> Silo, Jember
# ✅ [Seq] Berhasil -> Sukorambi, Jember
# ✅ [Seq] Berhasil -> Sukowono, Jember
# ✅ [Seq] Berhasil -> Sumberbaru, Jember
# ✅ [Seq] Berhasil -> Sumbersari, Jember
# ✅ [Seq] Berhasil -> Tanggul, Jember
# ✅ [Seq] Berhasil -> Tempurejo, Jember
# ✅ [Seq] Berhasil -> Umbulsari, Jember
# ✅ [Seq] Berhasil -> Wuluhan, Jember
# ✅ [Seq] Berhasil -> Bangorejo, Banyuwangi
# ✅ [Seq] Berhasil -> Banyuwangi, Banyuwangi
# ✅ [Seq] Berhasil -> Cluring, Banyuwangi
# ✅ [Seq] Berhasil -> Gambiran, Banyuwangi
# ✅ [Seq] Berhasil -> Genteng, Banyuwangi
# ✅ [Seq] Berhasil -> Giri, Banyuwangi
# ✅ [Seq] Berhasil -> Glagah, Banyuwangi
# ✅ [Seq] Berhasil -> Glenmore, Banyuwangi
# ✅ [Seq] Berhasil -> Kabat, Banyuwangi
# ✅ [Seq] Berhasil -> Kalibaru, Banyuwangi
# ✅ [Seq] Berhasil -> Kalipuro, Banyuwangi
# ✅ [Seq] Berhasil -> Licin, Banyuwangi
# ✅ [Seq] Berhasil -> Muncar, Banyuwangi
# ✅ [Seq] Berhasil -> Pesanggaran, Banyuwangi
# ✅ [Seq] Berhasil -> Purwoharjo, Banyuwangi
# ✅ [Seq] Berhasil -> Rogojampi, Banyuwangi
# ✅ [Seq] Berhasil -> Sempu, Banyuwangi
# ✅ [Seq] Berhasil -> Siliragung, Banyuwangi
# ✅ [Seq] Berhasil -> Singojuruh, Banyuwangi
# ✅ [Seq] Berhasil -> Songgon, Banyuwangi
# ✅ [Seq] Berhasil -> Srono, Banyuwangi
# ✅ [Seq] Berhasil -> Tegaldlimo, Banyuwangi
# ✅ [Seq] Berhasil -> Tegalsari, Banyuwangi
# ✅ [Seq] Berhasil -> Wongsorejo, Banyuwangi
# ✅ [Seq] Berhasil -> Arjasa, Situbondo
# ✅ [Seq] Berhasil -> Asembagus, Situbondo
# ✅ [Seq] Berhasil -> Banyuglugur, Situbondo
# ✅ [Seq] Berhasil -> Banyuputih, Situbondo
# ✅ [Seq] Berhasil -> Besuki, Situbondo
# ✅ [Seq] Berhasil -> Bungatan, Situbondo
# ✅ [Seq] Berhasil -> Jangkar, Situbondo
# ✅ [Seq] Berhasil -> Jatibanteng, Situbondo
# ✅ [Seq] Berhasil -> Kapongan, Situbondo
# ✅ [Seq] Berhasil -> Kendit, Situbondo
# ✅ [Seq] Berhasil -> Mangaran, Situbondo
# ✅ [Seq] Berhasil -> Mlandingan, Situbondo
# ✅ [Seq] Berhasil -> Panarukan, Situbondo
# ✅ [Seq] Berhasil -> Panji, Situbondo
# ✅ [Seq] Berhasil -> Situbondo, Situbondo
# ✅ [Seq] Berhasil -> Suboh, Situbondo
# ✅ [Seq] Berhasil -> Sumbermalang, Situbondo
# ✅ [Seq] Berhasil -> Binakal, Bondowoso
# ✅ [Seq] Berhasil -> Bondowoso, Bondowoso
# ✅ [Seq] Berhasil -> Botolinggo, Bondowoso
# ✅ [Seq] Berhasil -> Cermee, Bondowoso
# ✅ [Seq] Berhasil -> Curahdami, Bondowoso
# ✅ [Seq] Berhasil -> Grujugan, Bondowoso
# ✅ [Seq] Berhasil -> Jambesari Darus Sholah, Bondowoso
# ✅ [Seq] Berhasil -> Klabang, Bondowoso
# ✅ [Seq] Berhasil -> Maesan, Bondowoso
# ✅ [Seq] Berhasil -> Pakem, Bondowoso
# ✅ [Seq] Berhasil -> Prajekan, Bondowoso
# ✅ [Seq] Berhasil -> Pujer, Bondowoso
# ✅ [Seq] Berhasil -> Sempol, Bondowoso
# ✅ [Seq] Berhasil -> Sukosari, Bondowoso
# ✅ [Seq] Berhasil -> Sumberwringin, Bondowoso
# ✅ [Seq] Berhasil -> Taman Krocok, Bondowoso
# ✅ [Seq] Berhasil -> Tamanan, Bondowoso
# ✅ [Seq] Berhasil -> Tapen, Bondowoso
# ✅ [Seq] Berhasil -> Tegalampel, Bondowoso
# ✅ [Seq] Berhasil -> Tenggarang, Bondowoso
# ✅ [Seq] Berhasil -> Tlogosari, Bondowoso
# ✅ [Seq] Berhasil -> Wringin, Bondowoso
# ✅ [Seq] Berhasil -> Wonosari, Bondowoso
# ✅ [Seq] Berhasil -> Bantaran, Probolinggo
# ✅ [Seq] Berhasil -> Banyuanyar, Probolinggo
# ✅ [Seq] Berhasil -> Besuk, Probolinggo
# ✅ [Seq] Berhasil -> Dringu, Probolinggo
