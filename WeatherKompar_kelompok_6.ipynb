# %% [raw]
# Peter Abednego Wijaya 			235150300111013
# Gilang Shido Faizalhaq			235150300111011
# Rizqy Jauhary Atsaany			235150300111038

# %% [raw]
# Langkah 1, cek data-data yang disediakan pada weather API

# %%
import requests
import json # Menggunakan json

# --- KONFIGURASI ---
# API key
API_KEY = "242819b7dfe84b4488a34756251809" 
LOKASI_CONTOH = "Malang" # Coba ambil data untuk Malang
# --- AKHIR KONFIGURASI --

# URL endpoint dari WeatherAPI
url = f"http://api.weatherapi.com/v1/current.json?key={API_KEY}&q={LOKASI_CONTOH}&aqi=no"

print(f"Mengambil data cuaca untuk: {LOKASI_CONTOH}...")

try:
    response = requests.get(url, timeout=10)
    response.raise_for_status()  # Error jika status code bukan 2xx
    
    data = response.json()
    
    # Cetak seluruh response JSON dengan format yang rapi
    print("\n--- Struktur Data JSON Lengkap ---")
    print(json.dumps(data, indent=4))
    
except requests.exceptions.RequestException as e:
    print(f"Gagal mendapatkan data: {e}")
# Out:
# Mengambil data cuaca untuk: Malang...
#
# --- Struktur Data JSON Lengkap ---
# {
#     "location": {
#         "name": "Malang",
#         "region": "East Java",
#         "country": "Indonesia",
#         "lat": -7.9797,
#         "lon": 112.6304,
#         "tz_id": "Asia/Jakarta",
#         "localtime_epoch": 1758453324,
#         "localtime": "2025-09-21 18:15"
#     },
#     "current": {
#         "last_updated_epoch": 1758453300,
#         "last_updated": "2025-09-21 18:15",
#         "temp_c": 30.1,
#         "temp_f": 86.2,
#         "is_day": 0,
#         "condition": {
#             "text": "Light rain shower",
#             "icon": "//cdn.weatherapi.com/weather/64x64/night/353.png",
#             "code": 1240
#         },
#         "wind_mph": 2.2,
#         "wind_kph": 3.6,
#         "wind_degree": 226,
#         "wind_dir": "SW",
#         "pressure_mb": 1009.0,
#         "pressure_in": 29.8,
#         "precip_mm": 0.34,
#         "precip_in": 0.01,
#         "humidity": 75,
#         "cloud": 25,
#         "feelslike_c": 38.3,
#         "feelslike_f": 100.9,
#         "windchill_c": 24.5,
#         "windchill_f": 76.1,
#         "heatindex_c": 26.6,
#         "heatindex_f": 79.9,
#         "dewpoint_c": 21.4,
#         "dewpoint_f": 70.5,
#         "vis_km": 10.0,
#         "vis_miles": 6.0,
#         "uv": 0.0,
#         "gust_mph": 3.3,
#         "gust_kph": 5.3,
#         "short_rad": 0,
#         "diff_rad": 0,
#         "dni": 0,
#         "gti": 0
#     }
# }

# %% [raw]
# 2. Membuat file excel bernama "DaftarKecamatan" dan pada kolom pertama di isi kecamatan-kecamatan di Jawa Timur

# %% [raw]
# 3. Membuat script untuk membaca file Excel, mengambil data cuaca untuk setiap kecamatan menggunakan multi-threading, dan menuliskannya kembali ke file Excel yang sama.

# %%
# --- 1. IMPORT LIBRARY YANG DIBUTUHKAN ---
import pandas as pd  # Untuk membaca dan menulis file Excel
import requests      # Untuk mengirim permintaan ke API cuaca
import threading     # Untuk menjalankan banyak permintaan API secara bersamaan
from datetime import datetime # Untuk menghitung waktu eksekusi

# --- 2. KONFIGURASI UTAMA ---
# API key
API_KEY = "242819b7dfe84b4488a34756251809"
# Nama file Excel yang berisi daftar kecamatan
NAMA_FILE_EXCEL = "DaftarKecamatan_kelompok_6.xlsx"
# Nama kolom di file Excel yang akan dibaca
NAMA_KOLOM_KECAMATAN = "Kecamatan"

# --- 3. PERSIAPAN UNTUK MULTI-THREADING ---
# 'results' adalah list kosong untuk menyimpan data cuaca yang berhasil diambil dari setiap thread.
results = []
# 'lock' digunakan untuk memastikan tidak ada dua thread yang menulis ke list 'results' di waktu yang bersamaan (Race).
# Ini mencegah data menjadi korup atau hilang.
lock = threading.Lock()

# --- 4. FUNGSI UNTUK MENGAMBIL DATA CUACA (UNTUK SETIAP THREAD) ---
def get_weather_data(kecamatan, index):
    """
    Fungsi ini dijalankan oleh setiap thread. Satu thread untuk satu kecamatan.
    'kecamatan' adalah nama lokasi (misal: "Waru").
    'index' adalah nomor baris asli dari Excel agar data tidak tertukar.
    """
    # URL API diformat dengan API Key dan nama kecamatan yang spesifik
    url = f"http://api.weatherapi.com/v1/current.json?key={API_KEY}&q={kecamatan}&aqi=no"
    
    try:
        # Kirim permintaan GET ke URL. Timeout 10 detik.
        response = requests.get(url, timeout=10)
        # Jika status respons bukan 200 OK (misal: 404 Not Found), maka akan muncul error
        response.raise_for_status()
        # Ubah respons dari format JSON menjadi Python dictionary
        data = response.json()

        # Buat dictionary baru hanya dengan data yang kita butuhkan
        weather_info = {
            'Last Update': data['location']['localtime'],
            'Suhu (°C)': data['current']['temp_c'],
            'Kelembapan (%)': data['current']['humidity'],
            'Kondisi Cuaca': data['current']['condition']['text'],
            'Kecepatan Angin (km/h)': data['current']['wind_kph'],
            'Arah Angin': data['current']['wind_dir'],
            'Sinar UV': data['current']['uv']
        }
        print(f"✅ Berhasil -> {kecamatan}")

    except requests.exceptions.RequestException:
        # Jika terjadi error apapun (lokasi tidak ada, koneksi gagal, dll.)
        print(f"Gagal -> {kecamatan}")
        # Buat dictionary berisi pesan 'Error' untuk menandai kegagalan
        weather_info = {
            'Last Update': 'Error',
            'Suhu (°C)': 'Error',
            'Kelembapan (%)': 'Error',
            'Kondisi Cuaca': 'Error',
            'Kecepatan Angin (km/h)': 'Error', 
            'Arah Angin' : 'Error',
            'Sinar UV': 'Error'
        }

    # Sebelum menyimpan hasil, 'kunci' dulu list 'results'
    with lock:
        # Simpan hasil (baik data maupun error) bersama dengan nomor baris aslinya
        results.append({'index': index, 'data': weather_info})

# --- 5. FUNGSI UTAMA UNTUK MENJALANKAN SEMUANYA ---
def main():
    # Catat waktu mulai
    start_time = datetime.now()

    # Baca file Excel dan simpan datanya ke dalam sebuah DataFrame pandas
    df = pd.read_excel(NAMA_FILE_EXCEL, engine='openpyxl')
    
    # Buat list kosong untuk menampung semua thread yang akan dibuat
    threads = []
    
    print(f"Memulai pengambilan data untuk {len(df)} kecamatan...")

    # Looping untuk setiap baris di dalam DataFrame Excel
    for index, row in df.iterrows():
        # Ambil nama kecamatan dari kolom yang sudah ditentukan
        kecamatan = row[NAMA_KOLOM_KECAMATAN]
        # Jika nama kecamatan tidak kosong
        if pd.notna(kecamatan):
            # Buat thread baru. Targetnya adalah fungsi 'get_weather_data'.
            # Argumennya adalah nama kecamatan dan nomor barisnya.
            thread = threading.Thread(target=get_weather_data, args=(kecamatan, index))
            # Tambahkan thread yang baru dibuat ke dalam list 'threads'
            threads.append(thread)
            # Mulai jalankan thread
            thread.start()

    # Setelah semua thread dibuat dan dimulai, tunggu sampai semuanya selesai bekerja
    for thread in threads:
        thread.join()

    print("\nSemua thread selesai. Menulis data ke Excel...")

    # Loop melalui hasil yang sudah terkumpul dari semua thread
    for result in results:
        # Ambil nomor baris asli
        idx = result['index']
        # Loop melalui setiap item data (misal: 'Suhu (°C)': 30)
        for key, value in result['data'].items():
            # Masukkan nilai ke DataFrame di baris (idx) dan kolom (key) yang sesuai
            df.loc[idx, key] = value
            
    # Tulis ulang seluruh DataFrame yang sudah diperbarui ke file Excel yang sama
    # index=False berarti nomor baris dari pandas tidak akan ikut ditulis ke Excel
    df.to_excel(NAMA_FILE_EXCEL, index=False)
    
    # Catat waktu selesai
    end_time = datetime.now()
    
    print(f"\n✅ Selesai! Data cuaca telah ditulis ke '{NAMA_FILE_EXCEL}'.")
    print(f"Total waktu eksekusi: {end_time - start_time}")

# --- 6. MEMANGGIL FUNGSI UTAMA UNTUK MEMULAI SKRIP ---
if __name__ == "__main__":
    main()
# Out:
# Memulai pengambilan data untuk 591 kecamatan...
# ✅ Berhasil -> Benowo, Surabaya
# ✅ Berhasil -> Bulak, Surabaya
# ✅ Berhasil -> Bubutan, Surabaya
# ✅ Berhasil -> Semampir, Surabaya
# ✅ Berhasil -> Tegalsari, Surabaya
# ✅ Berhasil -> Tandes, Surabaya
# ✅ Berhasil -> Asemrowo, Surabaya
# ✅ Berhasil -> Sambikerep, Surabaya
# ✅ Berhasil -> Dukuh Pakis, Surabaya
# ✅ Berhasil -> Suko Manunggal, Surabaya
# ✅ Berhasil -> Simokerto, Surabaya
# ✅ Berhasil -> Wonocolo, Surabaya
# ✅ Berhasil -> Wonokromo, Surabaya
# ✅ Berhasil -> Candi, Sidoarjo
# ✅ Berhasil -> Tenggilis Mejoyo, Surabaya
# ✅ Berhasil -> Gedangan, Sidoarjo
# ✅ Berhasil -> Buduran, Sidoarjo
# ✅ Berhasil -> Porong, Sidoarjo
# ✅ Berhasil -> Taman, Sidoarjo
# ✅ Berhasil -> Tanggulangin, Sidoarjo
# ✅ Berhasil -> Sedati, Sidoarjo
# ✅ Berhasil -> Balong, Ponorogo
# ✅ Berhasil -> Prambon, Sidoarjo
# ✅ Berhasil -> Waru, Sidoarjo
# ✅ Berhasil -> Tarik, Sidoarjo
# ✅ Berhasil -> Sawahan, Surabaya
# ✅ Berhasil -> Rungkut, Surabaya
# ✅ Berhasil -> Babadan, Ponorogo
# ✅ Berhasil -> Badegan, Ponorogo
# ✅ Berhasil -> Pabean Cantian, Surabaya
# ✅ Berhasil -> Kauman, Ponorogo
# ✅ Berhasil -> Karang Pilang, Surabaya
# ✅ Berhasil -> Mlarak, Ponorogo
# ✅ Berhasil -> Jenangan, Ponorogo
# ✅ Berhasil -> Tambaksari, Surabaya
# ✅ Berhasil -> Bungkal, Ponorogo
# ✅ Berhasil -> Sukolilo, Surabaya
# ✅ Berhasil -> Jambon, Ponorogo
# ✅ Berhasil -> Mulyorejo, Surabaya
# ✅ Berhasil -> Gayungan, Surabaya
# ✅ Berhasil -> Jetis, Ponorogo
# ✅ Berhasil -> Wiyung, Surabaya
# ✅ Berhasil -> Gunung Anyar, Surabaya
# ✅ Berhasil -> Lakarsantri, Surabaya
# ✅ Berhasil -> Ponorogo, Ponorogo
# ✅ Berhasil -> Sawoo, Ponorogo
# ✅ Berhasil -> Sambit, Ponorogo
# ✅ Berhasil -> Krembangan, Surabaya
# ✅ Berhasil -> Pudak, Ponorogo
# ✅ Berhasil -> Krembung, Sidoarjo
# ✅ Berhasil -> Jabon, Sidoarjo
# ✅ Berhasil -> Sidoarjo, Sidoarjo
# ✅ Berhasil -> Sukorejo, Ponorogo
# ✅ Berhasil -> Sukodono, Sidoarjo
# ✅ Berhasil -> Donorojo, Pacitan
# ✅ Berhasil -> Tulangan, Sidoarjo
# ✅ Berhasil -> Sooko, Ponorogo
# ✅ Berhasil -> Balongbendo, Sidoarjo
# ✅ Berhasil -> Bandar, Pacitan
# ✅ Berhasil -> Jambangan, Surabaya
# ✅ Berhasil -> Slahung, Ponorogo
# ✅ Berhasil -> Arjosari, Pacitan
# ✅ Berhasil -> Siman, Ponorogo
# ✅ Berhasil -> Ngadirojo, Pacitan
# ✅ Berhasil -> Sampung, Ponorogo
# ✅ Berhasil -> Dongko, Trenggalek
# ✅ Berhasil -> Kenjeran, Surabaya
# ✅ Berhasil -> Bendungan, Trenggalek
# ✅ Berhasil -> Pacitan, Pacitan
# ✅ Berhasil -> Genteng, Surabaya
# ✅ Berhasil -> Punung, Pacitan
# ✅ Berhasil -> Munjungan, Trenggalek
# ✅ Berhasil -> Pogalan, Trenggalek
# ✅ Berhasil -> Kampak, Trenggalek
# ✅ Berhasil -> Tegalombo, Pacitan
# ✅ Berhasil -> Pule, Trenggalek
# ✅ Berhasil -> Kebonagung, Pacitan
# ✅ Berhasil -> Pakal, Surabaya
# ✅ Berhasil -> Karangan, Trenggalek
# ✅ Berhasil -> Sudimoro, Pacitan
# ✅ Berhasil -> Besuki, Tulungagung
# ✅ Berhasil -> Durenan, Trenggalek
# ✅ Berhasil -> Tugu, Trenggalek
# ✅ Berhasil -> Watulimo, Trenggalek
# ✅ Berhasil -> Ngrayun, Ponorogo
# ✅ Berhasil -> Gondang, Tulungagung
# ✅ Berhasil -> Kalidawir, Tulungagung
# ✅ Berhasil -> Nawangan, Pacitan
# ✅ Berhasil -> Ngunut, Tulungagung
# ✅ Berhasil -> Wonoayu, Sidoarjo
# ✅ Berhasil -> Pakel, Tulungagung
# ✅ Berhasil -> Bandung, Tulungagung
# ✅ Berhasil -> Ngantru, Tulungagung
# ✅ Berhasil -> Pagerwojo, Tulungagung
# ✅ Berhasil -> Pringkuku, Pacitan
# ✅ Berhasil -> Pulung, Ponorogo
# ✅ Berhasil -> Sendang, Tulungagung
# ✅ Berhasil -> Kedungwaru, Tulungagung
# ✅ Berhasil -> Suruh, Trenggalek
# ✅ Berhasil -> Tanggunggunung, Tulungagung
# ✅ Berhasil -> Tulungagung, Tulungagung
# ✅ Berhasil -> Ngebel, Ponorogo
# ✅ Berhasil -> Panggul, Trenggalek
# ✅ Berhasil -> Campurdarat, Tulungagung
# ✅ Berhasil -> Garum, Blitar
# ✅ Berhasil -> Gandusari, Blitar
# ✅ Berhasil -> Trenggalek, Trenggalek
# ✅ Berhasil -> Kademangan, Blitar
# ✅ Berhasil -> Boyolangu, Tulungagung
# ✅ Berhasil -> Doko, Blitar
# ✅ Berhasil -> Tulakan, Pacitan
# ✅ Berhasil -> Kauman, Tulungagung
# ✅ Berhasil -> Karangrejo, Tulungagung
# ✅ Berhasil -> Krian, Sidoarjo
# ✅ Berhasil -> Nglegok, Blitar
# ✅ Berhasil -> Panggungrejo, Blitar
# ✅ Berhasil -> Pucanglaban, Tulungagung
# ✅ Berhasil -> Srengat, Blitar
# ✅ Berhasil -> Bakung, Blitar
# ✅ Berhasil -> Rejotangan, Tulungagung
# ✅ Berhasil -> Sumbergempol, Tulungagung
# ✅ Berhasil -> Selopuro, Blitar
# ✅ Berhasil -> Gandusari, Trenggalek
# ✅ Berhasil -> Sananankulon, Blitar
# ✅ Berhasil -> Gubeng, Surabaya
# ✅ Berhasil -> Binangun, Blitar
# ✅ Berhasil -> Selorejo, Blitar
# ✅ Berhasil -> Banyakan, Kediri
# ✅ Berhasil -> Gampengrejo, Kediri
# ✅ Berhasil -> Ponggok, Blitar
# ✅ Berhasil -> Gurah, Kediri
# ✅ Berhasil -> Kandangan, Kediri
# ✅ Berhasil -> Kesamben, Blitar
# ✅ Berhasil -> Badas, Kediri
# ✅ Berhasil -> Kanigoro, Blitar
# ✅ Berhasil -> Kayen Kidul, Kediri
# ✅ Berhasil -> Sutojayan, Blitar
# ✅ Berhasil -> Udanawu, Blitar
# ✅ Berhasil -> Kepung, Kediri
# Gagal -> Kunjang, Kediri
# ✅ Berhasil -> Talun, Blitar
# ✅ Berhasil -> Wates, Blitar
# ✅ Berhasil -> Wonodadi, Blitar
# ✅ Berhasil -> Wlingi, Blitar
# ✅ Berhasil -> Wonotirto, Blitar
# ✅ Berhasil -> Grogol, Kediri
# ✅ Berhasil -> Kandat, Kediri
# ✅ Berhasil -> Ngasem, Kediri
# ✅ Berhasil -> Ngancar, Kediri
# ✅ Berhasil -> Plosoklaten, Kediri
# ✅ Berhasil -> Papar, Kediri
# ✅ Berhasil -> Semen, Kediri
# ✅ Berhasil -> Purwoasri, Kediri
# ✅ Berhasil -> Ringinrejo, Kediri
# ✅ Berhasil -> Kras, Kediri
# ✅ Berhasil -> Puncu, Kediri
# ✅ Berhasil -> Bantur, Malang
# ✅ Berhasil -> Ampelgading, Malang
# ✅ Berhasil -> Tarokan, Kediri
# ✅ Berhasil -> Pare, Kediri
# ✅ Berhasil -> Wates, Kediri
# ✅ Berhasil -> Dampit, Malang
# ✅ Berhasil -> Bululawang, Malang
# ✅ Berhasil -> Ngadiluwih, Kediri
# ✅ Berhasil -> Mojo, Kediri
# ✅ Berhasil -> Donomulyo, Malang
# ✅ Berhasil -> Kalipare, Malang
# ✅ Berhasil -> Gedangan, Malang
# ✅ Berhasil -> Jabung, Malang
# ✅ Berhasil -> Pagu, Kediri
# ✅ Berhasil -> Kepanjen, Malang
# ✅ Berhasil -> Karangploso, Malang
# ✅ Berhasil -> Kromengan, Malang
# ✅ Berhasil -> Plemahan, Kediri
# ✅ Berhasil -> Lawang, Malang
# ✅ Berhasil -> Ngantang, Malang
# ✅ Berhasil -> Pakis, Malang
# ✅ Berhasil -> Pagak, Malang
# ✅ Berhasil -> Ngajum, Malang
# ✅ Berhasil -> Poncokusumo, Malang
# ✅ Berhasil -> Sumberpucung, Malang
# ✅ Berhasil -> Sumbermanjing Wetan, Malang
# ✅ Berhasil -> Sukorambi, Jember
# ✅ Berhasil -> Banyuwangi, Banyuwangi
# ✅ Berhasil -> Balung, Jember
# ✅ Berhasil -> Kalisat, Jember
# ✅ Berhasil -> Dau, Malang
# ✅ Berhasil -> Tegalsari, Banyuwangi
# ✅ Berhasil -> Turen, Malang
# ✅ Berhasil -> Sumberbaru, Jember✅ Berhasil -> Ledokombo, Jember
# ✅ Berhasil -> Pakusari, Jember
# ✅ Berhasil -> Pagelaran, Malang
# ✅ Berhasil -> Ajung, Jember
#
# ✅ Berhasil -> Gumukmas, Jember
# ✅ Berhasil -> Silo, Jember
# ✅ Berhasil -> Bangorejo, Banyuwangi
# ✅ Berhasil -> Wagir, Malang
# ✅ Berhasil -> Umbulsari, Jember
# ✅ Berhasil -> Semboro, Jember
# ✅ Berhasil -> Glenmore, Banyuwangi
# ✅ Berhasil -> Kalibaru, Banyuwangi
# ✅ Berhasil -> Licin, Banyuwangi
# ✅ Berhasil -> Patrang, Jember
# ✅ Berhasil -> Puger, Jember
# ✅ Berhasil -> Wuluhan, Jember
# ✅ Berhasil -> Jelbuk, Jember
# ✅ Berhasil -> Tumpang, Malang
# ✅ Berhasil -> Srono, Banyuwangi
# ✅ Berhasil -> Wonosari, Malang
# ✅ Berhasil -> Sumbersari, Jember
# ✅ Berhasil -> Tempurejo, Jember
# ✅ Berhasil -> Ambulu, Jember
# ✅ Berhasil -> Tegaldlimo, Banyuwangi
# ✅ Berhasil -> Bangsalsari, Jember
# ✅ Berhasil -> Kasembon, Malang
# ✅ Berhasil -> Arjasa, Jember
# ✅ Berhasil -> Muncar, Banyuwangi
# ✅ Berhasil -> Wajak, Malang
# ✅ Berhasil -> Kapongan, Situbondo
# ✅ Berhasil -> Kencong, Jember
# ✅ Berhasil -> Singojuruh, Banyuwangi
# ✅ Berhasil -> Pujon, Malang
# ✅ Berhasil -> Panti, Jember
# ✅ Berhasil -> Mumbulsari, Jember
# ✅ Berhasil -> Gondanglegi, Malang
# ✅ Berhasil -> Kaliwates, Jember
# ✅ Berhasil -> Tirtoyudo, Malang
# ✅ Berhasil -> Jatibanteng, Situbondo
# ✅ Berhasil -> Mlandingan, Situbondo
# ✅ Berhasil -> Genteng, Banyuwangi
# ✅ Berhasil -> Singosari, Malang
# ✅ Berhasil -> Bungatan, Situbondo
# ✅ Berhasil -> Pakisaji, Malang
# ✅ Berhasil -> Tanggul, Jember
# ✅ Berhasil -> Jombang, Jember
# ✅ Berhasil -> Kalipuro, Banyuwangi
# ✅ Berhasil -> Jenggawah, Jember
# ✅ Berhasil -> Tajinan, Malang
# ✅ Berhasil -> Kabat, Banyuwangi
# ✅ Berhasil -> Gambiran, Banyuwangi
# ✅ Berhasil -> Jangkar, Situbondo
# ✅ Berhasil -> Sukowono, Jember
# ✅ Berhasil -> Mayang, Jember
# ✅ Berhasil -> Mangaran, Situbondo
# ✅ Berhasil -> Kendit, Situbondo
# ✅ Berhasil -> Giri, Banyuwangi
# ✅ Berhasil -> Asembagus, Situbondo
# ✅ Berhasil -> Cluring, Banyuwangi
# ✅ Berhasil -> Pesanggaran, Banyuwangi
# ✅ Berhasil -> Sempu, Banyuwangi
# ✅ Berhasil -> Rogojampi, Banyuwangi
# ✅ Berhasil -> Siliragung, Banyuwangi
# ✅ Berhasil -> Songgon, Banyuwangi
# ✅ Berhasil -> Purwoharjo, Banyuwangi
# ✅ Berhasil -> Glagah, Banyuwangi
# ✅ Berhasil -> Arjasa, Situbondo
# ✅ Berhasil -> Wongsorejo, Banyuwangi
# ✅ Berhasil -> Rambipuji, Jember
# ✅ Berhasil -> Sumbermalang, Situbondo
# ✅ Berhasil -> Tegalampel, Bondowoso
# ✅ Berhasil -> Situbondo, Situbondo
# ✅ Berhasil -> Wringin, Bondowoso
# ✅ Berhasil -> Sempol, Bondowoso
# ✅ Berhasil -> Grujugan, Bondowoso
# ✅ Berhasil -> Maesan, Bondowoso
# ✅ Berhasil -> Pujer, Bondowoso
# ✅ Berhasil -> Sumberwringin, Bondowoso
# ✅ Berhasil -> Panji, Situbondo
# ✅ Berhasil -> Binakal, Bondowoso
# ✅ Berhasil -> Taman Krocok, Bondowoso
# ✅ Berhasil -> Pakem, Bondowoso
# ✅ Berhasil -> Bantaran, Probolinggo
# ✅ Berhasil -> Besuk, Probolinggo
# ✅ Berhasil -> Tenggarang, Bondowoso
# ✅ Berhasil -> Suboh, Situbondo
# ✅ Berhasil -> Prajekan, Bondowoso
# ✅ Berhasil -> Banyuanyar, Probolinggo
# ✅ Berhasil -> Tamanan, Bondowoso
# ✅ Berhasil -> Banyuglugur, Situbondo
# ✅ Berhasil -> Wonosari, Bondowoso
# ✅ Berhasil -> Sukosari, Bondowoso
# ✅ Berhasil -> Tlogosari, Bondowoso
# ✅ Berhasil -> Besuki, Situbondo
# ✅ Berhasil -> Jambesari Darus Sholah, Bondowoso✅ Berhasil -> Dringu, Probolinggo
#
# ✅ Berhasil -> Botolinggo, Bondowoso
# ✅ Berhasil -> Gading, Probolinggo
# ✅ Berhasil -> Tapen, Bondowoso
# ✅ Berhasil -> Cermee, Bondowoso
# ✅ Berhasil -> Klabang, Bondowoso
# ✅ Berhasil -> Banyuputih, Situbondo
# ✅ Berhasil -> Curahdami, Bondowoso
# ✅ Berhasil -> Panarukan, Situbondo
# ✅ Berhasil -> Bondowoso, Bondowoso
# ✅ Berhasil -> Gending, Probolinggo
# ✅ Berhasil -> Kotaanyar, Probolinggo
# ✅ Berhasil -> Kuripan, Probolinggo
# ✅ Berhasil -> Maron, Probolinggo
# ✅ Berhasil -> Krucil, Probolinggo
# ✅ Berhasil -> Lumbang, Probolinggo
# ✅ Berhasil -> Leces, Probolinggo
# ✅ Berhasil -> Sukapura, Probolinggo
# ✅ Berhasil -> Sumberasih, Probolinggo
# ✅ Berhasil -> Paiton, Probolinggo
# ✅ Berhasil -> Tiris, Probolinggo
# ✅ Berhasil -> Wonomerto, Probolinggo
# ✅ Berhasil -> Beji, Pasuruan
# ✅ Berhasil -> Gondang Wetan, Pasuruan
# ✅ Berhasil -> Pakuniran, Probolinggo
# ✅ Berhasil -> Kraton, Pasuruan
# ✅ Berhasil -> Lekok, Pasuruan
# ✅ Berhasil -> Grati, Pasuruan
# ✅ Berhasil -> Pohjentrek, Pasuruan
# ✅ Berhasil -> Lumbang, Pasuruan
# ✅ Berhasil -> Sukorejo, Pasuruan
# ✅ Berhasil -> Rejoso, Pasuruan
# ✅ Berhasil -> Gempol, Pasuruan
# ✅ Berhasil -> Winongan, Pasuruan
# ✅ Berhasil -> Kraksaan, Probolinggo
# ✅ Berhasil -> Bareng, Jombang
# ✅ Berhasil -> Tosari, Pasuruan
# ✅ Berhasil -> Cukir, Jombang
# ✅ Berhasil -> Wonosari, Pasuruan
# ✅ Berhasil -> Kejayan, Pasuruan
# ✅ Berhasil -> Pandaan, Pasuruan
# ✅ Berhasil -> Bandar Kedung Mulyo, Jombang
# ✅ Berhasil -> Gudo, Jombang
# ✅ Berhasil -> Krejengan, Probolinggo
# ✅ Berhasil -> Kesamben, Jombang
# ✅ Berhasil -> Kudu, Jombang
# ✅ Berhasil -> Diwek, Jombang
# ✅ Berhasil -> Kabuh, Jombang
# ✅ Berhasil -> Pajarakan, Probolinggo
# ✅ Berhasil -> Jogoroto, Jombang
# ✅ Berhasil -> Perak, Jombang
# ✅ Berhasil -> Mojowarno, Jombang
# ✅ Berhasil -> Plandaan, Jombang
# ✅ Berhasil -> Peterongan, Jombang
# ✅ Berhasil -> Sumber, Probolinggo
# ✅ Berhasil -> Ploso, Jombang
# ✅ Berhasil -> Tegal Siwalan, Probolinggo
# ✅ Berhasil -> Mojoagung, Jombang
# ✅ Berhasil -> Bangil, Pasuruan
# ✅ Berhasil -> Sumobito, Jombang
# ✅ Berhasil -> Tongas, Probolinggo
# ✅ Berhasil -> Baron, Nganjuk
# ✅ Berhasil -> Nguling, Pasuruan
# ✅ Berhasil -> Tembelang, Jombang
# ✅ Berhasil -> Bagor, Nganjuk
# ✅ Berhasil -> Prigen, Pasuruan
# ✅ Berhasil -> Pasrepan, Pasuruan
# ✅ Berhasil -> Gondang, Nganjuk
# ✅ Berhasil -> Rembang, Pasuruan
# ✅ Berhasil -> Purwodadi, Pasuruan
# ✅ Berhasil -> Purwosari, Pasuruan
# ✅ Berhasil -> Tutur, Pasuruan
# ✅ Berhasil -> Berbek, Nganjuk
# ✅ Berhasil -> Jatikalen, Nganjuk
# ✅ Berhasil -> Kertosono, Nganjuk
# ✅ Berhasil -> Loceret, Nganjuk
# ✅ Berhasil -> Lengkong, Nganjuk
# ✅ Berhasil -> Ngetos, Nganjuk
# ✅ Berhasil -> Rejoso, Nganjuk
# ✅ Berhasil -> Sukomoro, Nganjuk
# ✅ Berhasil -> Wilangan, Nganjuk
# ✅ Berhasil -> Ngusikan, Jombang
# ✅ Berhasil -> Baureno, Bojonegoro
# ✅ Berhasil -> Puspo, Pasuruan
# ✅ Berhasil -> Gayam, Bojonegoro
# ✅ Berhasil -> Balen, Bojonegoro
# ✅ Berhasil -> Pace, Nganjuk
# ✅ Berhasil -> Kasiman, Bojonegoro
# ✅ Berhasil -> Megaluh, Jombang
# ✅ Berhasil -> Kepohbaru, Bojonegoro
# ✅ Berhasil -> Kalitidu, Bojonegoro
# ✅ Berhasil -> Dander, Bojonegoro
# ✅ Berhasil -> Jombang, Jombang
# ✅ Berhasil -> Ngasem, Bojonegoro
# ✅ Berhasil -> Malo, Bojonegoro
# ✅ Berhasil -> Margomulyo, Bojonegoro
# ✅ Berhasil -> Padangan, Bojonegoro
# ✅ Berhasil -> Purwosari, Bojonegoro
# ✅ Berhasil -> Sekar, Bojonegoro
# ✅ Berhasil -> Kapas, Bojonegoro
# ✅ Berhasil -> Kadewan, Bojonegoro
# ✅ Berhasil -> Tambakrejo, Bojonegoro
# ✅ Berhasil -> Ngoro, Jombang
# ✅ Berhasil -> Sukosewu, Bojonegoro
# ✅ Berhasil -> Sawahan, Nganjuk
# ✅ Berhasil -> Trucuk, Bojonegoro
# ✅ Berhasil -> Ngambon, Bojonegoro
# ✅ Berhasil -> Brondong, Lamongan
# ✅ Berhasil -> Bluluk, Lamongan
# ✅ Berhasil -> Sugihwaras, Bojonegoro
# ✅ Berhasil -> Patianrowo, Nganjuk
# ✅ Berhasil -> Kedungpring, Lamongan
# ✅ Berhasil -> Sumberrejo, Bojonegoro
# ✅ Berhasil -> Prambon, Nganjuk
# ✅ Berhasil -> Ngronggot, Nganjuk
# ✅ Berhasil -> Nganjuk, Nganjuk
# ✅ Berhasil -> Karanggeneng, Lamongan
# ✅ Berhasil -> Ngluyu, Nganjuk
# ✅ Berhasil -> Tanjunganom, Nganjuk
# ✅ Berhasil -> Maduran, Lamongan
# ✅ Berhasil -> Bojonegoro, Bojonegoro
# ✅ Berhasil -> Temayang, Bojonegoro
# ✅ Berhasil -> Bubulan, Bojonegoro
# ✅ Berhasil -> Lamongan, Lamongan
# ✅ Berhasil -> Kembangbahu, Lamongan
# ✅ Berhasil -> Kalitengah, Lamongan
# ✅ Berhasil -> Laren, Lamongan
# ✅ Berhasil -> Pucuk, Lamongan
# ✅ Berhasil -> Sekaran, Lamongan
# ✅ Berhasil -> Ngimbang, Lamongan
# ✅ Berhasil -> Kedungadem, Bojonegoro
# ✅ Berhasil -> Solokuro, Lamongan
# ✅ Berhasil -> Sukorame, Lamongan
# ✅ Berhasil -> Sambeng, Lamongan
# ✅ Berhasil -> Paciran, Lamongan
# ✅ Berhasil -> Sarirejo, Lamongan
# ✅ Berhasil -> Turi, Lamongan
# ✅ Berhasil -> Gondang, Bojonegoro
# ✅ Berhasil -> Ngraho, Bojonegoro
# ✅ Berhasil -> Mantup, Lamongan
# ✅ Berhasil -> Kenduruan, Tuban
# ✅ Berhasil -> Bangilan, Tuban
# ✅ Berhasil -> Babat, Lamongan
# ✅ Berhasil -> Jatirogo, Tuban
# ✅ Berhasil -> Deket, Lamongan
# ✅ Berhasil -> Glagah, Lamongan
# ✅ Berhasil -> Parengan, Tuban
# ✅ Berhasil -> Plumpang, Tuban
# ✅ Berhasil -> Rengel, Tuban
# ✅ Berhasil -> Modo, Lamongan
# ✅ Berhasil -> Tambakboyo, Tuban
# ✅ Berhasil -> Semanding, Tuban
# ✅ Berhasil -> Soko, Tuban
# ✅ Berhasil -> Balongpanggang, Gresik
# ✅ Berhasil -> Grabagan, Tuban
# ✅ Berhasil -> Tuban, Tuban
# ✅ Berhasil -> Merakurak, Tuban
# ✅ Berhasil -> Tikung, Lamongan
# ✅ Berhasil -> Widang, Tuban
# ✅ Berhasil -> Sukodadi, Lamongan
# ✅ Berhasil -> Jenu, Tuban
# ✅ Berhasil -> Cerme, Gresik
# ✅ Berhasil -> Singgahan, Tuban
# ✅ Berhasil -> Benjeng, Gresik
# ✅ Berhasil -> Sugio, Lamongan
# ✅ Berhasil -> Bungah, Gresik
# ✅ Berhasil -> Driyorejo, Gresik
# ✅ Berhasil -> Gresik, Gresik
# ✅ Berhasil -> Duduk Sampeyan, Gresik
# ✅ Berhasil -> Senori, Tuban
# ✅ Berhasil -> Kerek, Tuban
# ✅ Berhasil -> Karangbinangun, Lamongan
# ✅ Berhasil -> Bancar, Tuban
# ✅ Berhasil -> Menganti, Gresik
# ✅ Berhasil -> Manyar, Gresik
# ✅ Berhasil -> Palang, Tuban
# ✅ Berhasil -> Panceng, Gresik
# ✅ Berhasil -> Ujung Pangkah, Gresik
# ✅ Berhasil -> Montong, Tuban
# ✅ Berhasil -> Tambak, Gresik
# ✅ Berhasil -> Bangkalan, Bangkalan
# ✅ Berhasil -> Wringinanom, Gresik
# ✅ Berhasil -> Kebomas, Gresik
# ✅ Berhasil -> Sidayu, Gresik
# ✅ Berhasil -> Burneh, Bangkalan
# ✅ Berhasil -> Blega, Bangkalan
# ✅ Berhasil -> Galis, Bangkalan
# ✅ Berhasil -> Klampis, Bangkalan
# ✅ Berhasil -> Kokop, Bangkalan
# ✅ Berhasil -> Geger, Bangkalan
# ✅ Berhasil -> Konang, Bangkalan
# ✅ Berhasil -> Dukun, Gresik
# ✅ Berhasil -> Labang, Bangkalan
# ✅ Berhasil -> Socah, Bangkalan
# ✅ Berhasil -> Sangkapura, Gresik
# ✅ Berhasil -> Arosbaya, Bangkalan
# ✅ Berhasil -> Tragah, Bangkalan
# ✅ Berhasil -> Banyuates, Sampang
# ✅ Berhasil -> Jrengik, Sampang
# ✅ Berhasil -> Tanjungbumi, Bangkalan
# ✅ Berhasil -> Karang Penang, Sampang
# ✅ Berhasil -> Kedamean, Gresik
# ✅ Berhasil -> Kamal, Bangkalan
# ✅ Berhasil -> Pangarengan, Sampang
# ✅ Berhasil -> Sampang, Sampang
# ✅ Berhasil -> Robatal, Sampang
# ✅ Berhasil -> Sreseh, Sampang
# ✅ Berhasil -> Torjun, Sampang
# ✅ Berhasil -> Bluto, Sumenep
# ✅ Berhasil -> Sepulu, Bangkalan
# ✅ Berhasil -> Dungkek, Sumenep
# ✅ Berhasil -> Dasuk, Sumenep
# ✅ Berhasil -> Tanah Merah, Bangkalan
# ✅ Berhasil -> Kota Sumenep, Sumenep
# ✅ Berhasil -> Lenteng, Sumenep
# ✅ Berhasil -> Giliginting, Sumenep
# ✅ Berhasil -> Kwanyar, Bangkalan
# ✅ Berhasil -> Batuan, Sumenep
# ✅ Berhasil -> Guluk-Guluk, Sumenep
# ✅ Berhasil -> Camplong, Sampang
# ✅ Berhasil -> Ganding, Sumenep
# ✅ Berhasil -> Nonggunong, Sumenep
# ✅ Berhasil -> Pasongsongan, Sumenep
# ✅ Berhasil -> Kedungdung, Sampang
# ✅ Berhasil -> Gubeng, Surabaya
# ✅ Berhasil -> Rubaru, Sumenep
# ✅ Berhasil -> Ketapang, Sampang
# ✅ Berhasil -> Ambunten, Sumenep
# ✅ Berhasil -> Talango, Sumenep
# ✅ Berhasil -> Sapeken, Sumenep
# ✅ Berhasil -> Arjasa, Sumenep
# ✅ Berhasil -> Batang Batang, Sumenep
# ✅ Berhasil -> Tambelangan, Sampang
# ✅ Berhasil -> Larangan, Pamekasan
# ✅ Berhasil -> Sokobanah, Sampang
# ✅ Berhasil -> Gapura, Sumenep
# ✅ Berhasil -> Batumarmar, Pamekasan
# ✅ Berhasil -> Pakong, Pamekasan
# ✅ Berhasil -> Batuputih, Sumenep
# ✅ Berhasil -> Modung, Bangkalan
# ✅ Berhasil -> Pegantenan, Pamekasan
# ✅ Berhasil -> Pasean, Pamekasan
# ✅ Berhasil -> Waru, Pamekasan
# ✅ Berhasil -> Palenggaan, Pamekasan
# ✅ Berhasil -> Pamekasan, Pamekasan
# ✅ Berhasil -> Proppo, Pamekasan
# ✅ Berhasil -> Kangayan, Sumenep
# ✅ Berhasil -> Kalianget, Sumenep
# ✅ Berhasil -> Dlanggu, Mojokerto
# ✅ Berhasil -> Kadur, Pamekasan
# ✅ Berhasil -> Dawarblandong, Mojokerto
# ✅ Berhasil -> Omben, Sampang
# ✅ Berhasil -> Masalembu, Sumenep
# ✅ Berhasil -> Manding, Sumenep
# ✅ Berhasil -> Gedeg, Mojokerto
# ✅ Berhasil -> Kemlagi, Mojokerto
# ✅ Berhasil -> Kutorejo, Mojokerto
# ✅ Berhasil -> Tlanakan, Pamekasan
# ✅ Berhasil -> Gondang, Mojokerto
# ✅ Berhasil -> Pungging, Mojokerto
# ✅ Berhasil -> Pragaan, Sumenep
# ✅ Berhasil -> Ra'as, Sumenep
# ✅ Berhasil -> Pacet, Mojokerto
# ✅ Berhasil -> Saronggi, Sumenep
# ✅ Berhasil -> Puri, Mojokerto
# ✅ Berhasil -> Ngoro, Mojokerto
# ✅ Berhasil -> Gayam, Sumenep
# ✅ Berhasil -> Galis, Pamekasan
# ✅ Berhasil -> Bangsal, Mojokerto
# ✅ Berhasil -> Bumiaji, Batu
# ✅ Berhasil -> Sooko, Mojokerto
# ✅ Berhasil -> Batu, Batu
# ✅ Berhasil -> Pademawu, Pamekasan
# ✅ Berhasil -> Mojosari, Mojokerto
# ✅ Berhasil -> Junrejo, Batu
# ✅ Berhasil -> Sananwetan, Blitar
# ✅ Berhasil -> Sukorejo, Blitar
# ✅ Berhasil -> Purworejo, Pasuruan
# ✅ Berhasil -> Kanigaran, Probolinggo
# ✅ Berhasil -> Kedopok, Probolinggo
# ✅ Berhasil -> Pesantren, Kediri
# ✅ Berhasil -> Kota Kediri, Kediri
# ✅ Berhasil -> Bugul Kidul, Pasuruan
# ✅ Berhasil -> Panggungrejo, Pasuruan
# ✅ Berhasil -> Jatirejo, Mojokerto
# ✅ Berhasil -> Mojoroto, Kediri
# ✅ Berhasil -> Karangpilang, Surabaya
# ✅ Berhasil -> Prajurit Kulon, Mojokerto
# ✅ Berhasil -> Mojoanyar, Mojokerto
# ✅ Berhasil -> Magersari, Mojokerto
# ✅ Berhasil -> Trowulan, Mojokerto
# ✅ Berhasil -> Blimbing, Malang
# ✅ Berhasil -> Klojen, Malang
# ✅ Berhasil -> Kedungkandang, Malang
# ✅ Berhasil -> Lowokwaru, Malang
# ✅ Berhasil -> Kepanjenkidul, Blitar
# ✅ Berhasil -> Jetis, Mojokerto
# ✅ Berhasil -> Manguharjo, Madiun
# ✅ Berhasil -> Sukun, Malang
# ✅ Berhasil -> Wonoasih, Probolinggo
# ✅ Berhasil -> Trawas, Mojokerto
# ✅ Berhasil -> Mayangan, Probolinggo
# ✅ Berhasil -> Gadingrejo, Pasuruan
# ✅ Berhasil -> Kademangan, Probolinggo
# ✅ Berhasil -> Taman, Madiun
# ✅ Berhasil -> Kartoharjo, Madiun
#
# Semua thread selesai. Menulis data ke Excel...
# C:\Users\peter\AppData\Local\Temp\ipykernel_10016\3817088020.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Error' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[idx, key] = value
# C:\Users\peter\AppData\Local\Temp\ipykernel_10016\3817088020.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Error' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[idx, key] = value
# C:\Users\peter\AppData\Local\Temp\ipykernel_10016\3817088020.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Error' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[idx, key] = value
# C:\Users\peter\AppData\Local\Temp\ipykernel_10016\3817088020.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Error' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[idx, key] = value
# ✅ Selesai! Data cuaca telah ditulis ke 'DaftarKecamatan.xlsx'.
# Total waktu eksekusi: 0:00:03.443390
