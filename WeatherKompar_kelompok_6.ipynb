# %% [markdown]
# # Kelompok:
# #### Peter Abednego Wijaya 			235150300111013
# #### Gilang Shido Faizalhaq			235150300111011
# #### Rizqy Jauhary Atsaany			235150300111038

# %% [markdown]
# ## Pastikan install library terlebih dahulu. Run di terminal:
# ### pip install pandas requests openpyxl

# %% [markdown]
# ## Langkah 1, cek data-data yang disediakan pada weather API

# %%
import requests
import json # Menggunakan json

# --- KONFIGURASI ---
# API key
API_KEY = "242819b7dfe84b4488a34756251809" 
LOKASI_CONTOH = "Malang" # Coba ambil data untuk Malang
# --- AKHIR KONFIGURASI --

# URL endpoint dari WeatherAPI
url = f"http://api.weatherapi.com/v1/current.json?key={API_KEY}&q={LOKASI_CONTOH}&aqi=no"

print(f"Mengambil data cuaca untuk: {LOKASI_CONTOH}...")

try:
    response = requests.get(url, timeout=10)
    response.raise_for_status()  # Error jika status code bukan 2xx
    
    data = response.json()
    
    # Cetak seluruh response JSON dengan format yang rapi
    print("\n--- Struktur Data JSON Lengkap ---")
    print(json.dumps(data, indent=4))
    
except requests.exceptions.RequestException as e:
    print(f"Gagal mendapatkan data: {e}")
# Out:
# Mengambil data cuaca untuk: Malang...
#
# --- Struktur Data JSON Lengkap ---
# {
#     "location": {
#         "name": "Malang",
#         "region": "East Java",
#         "country": "Indonesia",
#         "lat": -7.9797,
#         "lon": 112.6304,
#         "tz_id": "Asia/Jakarta",
#         "localtime_epoch": 1758774178,
#         "localtime": "2025-09-25 11:22"
#     },
#     "current": {
#         "last_updated_epoch": 1758773700,
#         "last_updated": "2025-09-25 11:15",
#         "temp_c": 33.1,
#         "temp_f": 91.6,
#         "is_day": 1,
#         "condition": {
#             "text": "Patchy rain nearby",
#             "icon": "//cdn.weatherapi.com/weather/64x64/day/176.png",
#             "code": 1063
#         },
#         "wind_mph": 2.2,
#         "wind_kph": 3.6,
#         "wind_degree": 316,
#         "wind_dir": "NW",
#         "pressure_mb": 1010.0,
#         "pressure_in": 29.83,
#         "precip_mm": 0.07,
#         "precip_in": 0.0,
#         "humidity": 56,
#         "cloud": 25,
#         "feelslike_c": 35.8,
#         "feelslike_f": 96.4,
#         "windchill_c": 30.7,
#         "windchill_f": 87.2,
#         "heatindex_c": 31.7,
#         "heatindex_f": 89.1,
#         "dewpoint_c": 17.4,
#         "dewpoint_f": 63.2,
#         "vis_km": 10.0,
#         "vis_miles": 6.0,
#         "uv": 11.5,
#         "gust_mph": 6.7,
#         "gust_kph": 10.8,
#         "short_rad": 764.96,
#         "diff_rad": 103.66,
#         "dni": 0.0,
#         "gti": 103.9
#     }
# }

# %% [markdown]
# # 2. Membuat file excel bernama "DaftarKecamatan" dan pada kolom pertama di isi kecamatan-kecamatan di Jawa Timur

# %% [markdown]
# # 3. Membuat script untuk membaca file Excel, mengambil data cuaca untuk setiap kecamatan menggunakan multi-threading, dan menuliskannya kembali ke file Excel yang sama.

# %%
# --- 1. IMPORT LIBRARY YANG DIBUTUHKAN ---
import pandas as pd
import requests
import threading
from datetime import datetime

# --- 2. KONFIGURASI UTAMA ---
API_KEY = "242819b7dfe84b4488a34756251809"
NAMA_FILE_EXCEL = "DaftarKecamatan_kelompok_6.xlsx"
NAMA_KOLOM_KECAMATAN = "Kecamatan"

# =========== BAGIAN UNTUK METODE MULTI-THREADING =============

# --- 3A. PERSIAPAN UNTUK MULTI-THREADING ---
results = []
lock = threading.Lock()

# --- 4A. FUNGSI GET DATA (UNTUK THREAD) ---
def get_weather_data_threaded(kecamatan, index):
    """Fungsi ini dijalankan oleh setiap thread. Hasilnya disimpan di list global 'results'."""
    url = f"http://api.weatherapi.com/v1/current.json?key={API_KEY}&q={kecamatan}&aqi=no"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        weather_info = {
            'Last Update': data['location']['localtime'],
            'Suhu (°C)': data['current']['temp_c'],
            'Kelembapan (%)': data['current']['humidity'],
            'Kondisi Cuaca': data['current']['condition']['text'],
            'Kecepatan Angin (km/h)': data['current']['wind_kph'],
            'Arah Angin': data['current']['wind_dir'],
            'Sinar UV': data['current']['uv'],
            'Cloud ': data['current']['cloud']
        }
        print(f"✅ [Thread] Berhasil -> {kecamatan}")
    except requests.exceptions.RequestException:
        print(f"❌ [Thread] Gagal    -> {kecamatan}")
        weather_info = {
            'Last Update': 'Error', 'Suhu (°C)': 'Error', 'Kelembapan (%)': 'Error',
            'Kondisi Cuaca': 'Error', 'Kecepatan Angin (km/h)': 'Error',
            'Arah Angin' : 'Error', 'Sinar UV': 'Error'
        }
    with lock:
        results.append({'index': index, 'data': weather_info})

# --- 5A. FUNGSI UTAMA (MULTI-THREAD) ---
def run_w_multithread():
    start_time = datetime.now()
    df = pd.read_excel(NAMA_FILE_EXCEL, engine='openpyxl')
    threads = []
    
    # Kosongkan list results setiap kali fungsi dijalankan
    results.clear()
    
    print(f"🚀 Memulai pengambilan data untuk {len(df)} kecamatan (Multi-Thread)...")
    for index, row in df.iterrows():
        kecamatan = row[NAMA_KOLOM_KECAMATAN]
        if pd.notna(kecamatan):
            thread = threading.Thread(target=get_weather_data_threaded, args=(kecamatan, index))
            threads.append(thread)
            thread.start()

    for thread in threads:
        thread.join()

    print("\nSemua thread selesai. Menulis data ke Excel...")
    for result in results:
        idx = result['index']
        for key, value in result['data'].items():
            df.loc[idx, key] = value
            
    df.to_excel(NAMA_FILE_EXCEL, index=False)
    end_time = datetime.now()
    print(f"\n✅ Selesai! Data cuaca telah ditulis ke '{NAMA_FILE_EXCEL}'.")
    print(f"Total waktu eksekusi (Multi-Thread): {end_time - start_time}")

# =========== BAGIAN UNTUK METODE SEQUENTIAL ============

# --- 4B. FUNGSI GET DATA (UNTUK SEQUENTIAL) ---
def get_weather_data_sequential(kecamatan):
    """Fungsi ini dijalankan satu per satu. Hasilnya langsung di-'return'."""
    url = f"http://api.weatherapi.com/v1/current.json?key={API_KEY}&q={kecamatan}&aqi=no"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        weather_info = {
            'Last Update': data['location']['localtime'],
            'Suhu (°C)': data['current']['temp_c'],
            'Kelembapan (%)': data['current']['humidity'],
            'Kondisi Cuaca': data['current']['condition']['text'],
            'Kecepatan Angin (km/h)': data['current']['wind_kph'],
            'Arah Angin': data['current']['wind_dir'],
            'Sinar UV': data['current']['uv']
        }
        print(f"✅ [Seq] Berhasil -> {kecamatan}")
    except requests.exceptions.RequestException:
        print(f"❌ [Seq] Gagal    -> {kecamatan}")
        weather_info = {
            'Last Update': 'Error', 'Suhu (°C)': 'Error', 'Kelembapan (%)': 'Error',
            'Kondisi Cuaca': 'Error', 'Kecepatan Angin (km/h)': 'Error', 
            'Arah Angin' : 'Error', 'Sinar UV': 'Error'
        }
    return weather_info

# --- 5B. FUNGSI UTAMA (SEQUENTIAL) ---
def run_sequentially():
    start_time = datetime.now()
    df = pd.read_excel(NAMA_FILE_EXCEL, engine='openpyxl')
    
    print(f"🐢 Memulai pengambilan data untuk {len(df)} kecamatan (Sekuensial)...")
    for index, row in df.iterrows():
        kecamatan = row[NAMA_KOLOM_KECAMATAN]
        if pd.notna(kecamatan):
            weather_data = get_weather_data_sequential(kecamatan)
            for key, value in weather_data.items():
                df.loc[index, key] = value
            
    print("\nSemua data telah diambil. Menulis data ke Excel...")
    df.to_excel(NAMA_FILE_EXCEL, index=False)
    end_time = datetime.now()
    print(f"\n✅ Selesai! Data cuaca telah ditulis ke '{NAMA_FILE_EXCEL}'.")
    print(f"Total waktu eksekusi (Sekuensial): {end_time - start_time}")


# ======================== PANEL KONTROL EKSEKUSI ===========================
if __name__ == "__main__":
    # --- Pilihan 1: Mode Cepat (Multi-Thread) ---
     run_w_multithread()
    
    # --- Pilihan 2: Mode Sabar (Sekuensial) ---
    #run_sequentially()
# Out:
# 🚀 Memulai pengambilan data untuk 591 kecamatan (Multi-Thread)...
# ✅ [Thread] Berhasil -> Sedati, Sidoarjo
# ✅ [Thread] Berhasil -> Kenjeran, Surabaya
# ✅ [Thread] Berhasil -> Kauman, Ponorogo
# ✅ [Thread] Berhasil -> Bungkal, Ponorogo
# ✅ [Thread] Berhasil -> Sukorejo, Ponorogo
# ✅ [Thread] Berhasil -> Sambit, Ponorogo
# ✅ [Thread] Berhasil -> Suko Manunggal, Surabaya
# ✅ [Thread] Berhasil -> Asemrowo, Surabaya
# ✅ [Thread] Berhasil -> Bandar, Pacitan
# ✅ [Thread] Berhasil -> Tenggilis Mejoyo, Surabaya
# ✅ [Thread] Berhasil -> Wonocolo, Surabaya
# ✅ [Thread] Berhasil -> Pabean Cantian, Surabaya
# ✅ [Thread] Berhasil -> Porong, Sidoarjo
# ✅ [Thread] Berhasil -> Ngrayun, Ponorogo
# ✅ [Thread] Berhasil -> Bubutan, Surabaya
# ✅ [Thread] Berhasil -> Jabon, Sidoarjo
# ✅ [Thread] Berhasil -> Benowo, Surabaya
# ✅ [Thread] Berhasil -> Gayungan, Surabaya
# ✅ [Thread] Berhasil -> Pudak, Ponorogo
# ✅ [Thread] Berhasil -> Pakal, Surabaya
# ✅ [Thread] Berhasil -> Wonokromo, Surabaya
# ✅ [Thread] Berhasil -> Sukolilo, Surabaya
# ✅ [Thread] Berhasil -> Genteng, Surabaya
# ✅ [Thread] Berhasil -> Tambaksari, Surabaya
# ✅ [Thread] Berhasil -> Dukuh Pakis, Surabaya
# ✅ [Thread] Berhasil -> Buduran, Sidoarjo
# ✅ [Thread] Berhasil -> Prambon, Sidoarjo
# ✅ [Thread] Berhasil -> Wiyung, Surabaya
# ✅ [Thread] Berhasil -> Gedangan, Sidoarjo
# ✅ [Thread] Berhasil -> Balong, Ponorogo
# ✅ [Thread] Berhasil -> Sawoo, Ponorogo
# ✅ [Thread] Berhasil -> Sawahan, Surabaya
# ✅ [Thread] Berhasil -> Babadan, Ponorogo
# ✅ [Thread] Berhasil -> Sampung, Ponorogo
# ✅ [Thread] Berhasil -> Sambikerep, Surabaya
# ✅ [Thread] Berhasil -> Badegan, Ponorogo
# ✅ [Thread] Berhasil -> Karang Pilang, Surabaya
# ✅ [Thread] Berhasil -> Lakarsantri, Surabaya
# ✅ [Thread] Berhasil -> Krembangan, Surabaya
# ✅ [Thread] Berhasil -> Wonoayu, Sidoarjo
# ✅ [Thread] Berhasil -> Pulung, Ponorogo
# ✅ [Thread] Berhasil -> Jenangan, Ponorogo
# ✅ [Thread] Berhasil -> Kebonagung, Pacitan
# ✅ [Thread] Berhasil -> Jetis, Ponorogo
# ✅ [Thread] Berhasil -> Sidoarjo, Sidoarjo
# ✅ [Thread] Berhasil -> Siman, Ponorogo
# ✅ [Thread] Berhasil -> Semampir, Surabaya
# ✅ [Thread] Berhasil -> Balongbendo, Sidoarjo
# ✅ [Thread] Berhasil -> Sooko, Ponorogo
# ✅ [Thread] Berhasil -> Jambangan, Surabaya
# ✅ [Thread] Berhasil -> Slahung, Ponorogo
# ✅ [Thread] Berhasil -> Mulyorejo, Surabaya
# ✅ [Thread] Berhasil -> Sukodono, Sidoarjo
# ✅ [Thread] Berhasil -> Ngebel, Ponorogo
# ✅ [Thread] Berhasil -> Rungkut, Surabaya
# ✅ [Thread] Berhasil -> Krembung, Sidoarjo
# ✅ [Thread] Berhasil -> Simokerto, Surabaya
# ✅ [Thread] Berhasil -> Gubeng, Surabaya
# ✅ [Thread] Berhasil -> Ponorogo, Ponorogo
# ✅ [Thread] Berhasil -> Jambon, Ponorogo
# ✅ [Thread] Berhasil -> Krian, Sidoarjo
# ✅ [Thread] Berhasil -> Tarik, Sidoarjo
# ✅ [Thread] Berhasil -> Tegalsari, Surabaya
# ✅ [Thread] Berhasil -> Gunung Anyar, Surabaya
# ✅ [Thread] Berhasil -> Tulangan, Sidoarjo
# ✅ [Thread] Berhasil -> Tanggulangin, Sidoarjo
# ✅ [Thread] Berhasil -> Tandes, Surabaya
# ✅ [Thread] Berhasil -> Bulak, Surabaya
# ✅ [Thread] Berhasil -> Waru, Sidoarjo
# ✅ [Thread] Berhasil -> Gampengrejo, Kediri
# ✅ [Thread] Berhasil -> Grogol, Kediri
# ✅ [Thread] Berhasil -> Gurah, Kediri
# ✅ [Thread] Berhasil -> Sumbermanjing Wetan, Malang
# ✅ [Thread] Berhasil -> Pule, Trenggalek
# ✅ [Thread] Berhasil -> Dongko, Trenggalek
# ✅ [Thread] Berhasil -> Gandusari, Blitar
# ✅ [Thread] Berhasil -> Ngantang, Malang
# ✅ [Thread] Berhasil -> Binangun, Blitar✅ [Thread] Berhasil -> Ampelgading, Malang
# ✅ [Thread] Berhasil -> Talun, Blitar
# ✅ [Thread] Berhasil -> Pogalan, Trenggalek
# ✅ [Thread] Berhasil -> Bendungan, Trenggalek
# ✅ [Thread] Berhasil -> Wonosari, Malang
# ✅ [Thread] Berhasil -> Dau, Malang
# ✅ [Thread] Berhasil -> Poncokusumo, Malang
# ✅ [Thread] Berhasil -> Kademangan, Blitar
# ✅ [Thread] Berhasil -> Wonotirto, Blitar
#
# ✅ [Thread] Berhasil -> Kalisat, Jember
# ✅ [Thread] Berhasil -> Kampak, Trenggalek
# ✅ [Thread] Berhasil -> Suruh, Trenggalek
# ✅ [Thread] Berhasil -> Mlarak, Ponorogo
# ✅ [Thread] Berhasil -> Candi, Sidoarjo
# ✅ [Thread] Berhasil -> Plemahan, Kediri
# ✅ [Thread] Berhasil -> Badas, Kediri
# ✅ [Thread] Berhasil -> Selorejo, Blitar
# ✅ [Thread] Berhasil -> Kepanjen, Malang
# ✅ [Thread] Berhasil -> Gedangan, Malang
# ✅ [Thread] Berhasil -> Srengat, Blitar
# ✅ [Thread] Berhasil -> Jombang, Jember
# ✅ [Thread] Berhasil -> Munjungan, Trenggalek
# ✅ [Thread] Berhasil -> Gandusari, Trenggalek
# ✅ [Thread] Berhasil -> Trenggalek, Trenggalek
# ✅ [Thread] Berhasil -> Ngajum, Malang
# ✅ [Thread] Berhasil -> Kanigoro, Blitar
# ✅ [Thread] Berhasil -> Panti, Jember
# ✅ [Thread] Berhasil -> Purwoasri, Kediri
# ✅ [Thread] Berhasil -> Pare, Kediri
# ✅ [Thread] Berhasil -> Mumbulsari, Jember
# ✅ [Thread] Berhasil -> Punung, Pacitan
# ✅ [Thread] Berhasil -> Tugu, Trenggalek
# ✅ [Thread] Berhasil -> Nawangan, Pacitan
# ✅ [Thread] Berhasil -> Pakis, Malang
# ✅ [Thread] Berhasil -> Ambulu, Jember
# ✅ [Thread] Berhasil -> Kepung, Kediri
# ✅ [Thread] Berhasil -> Puncu, Kediri
# ✅ [Thread] Berhasil -> Nglegok, Blitar
# ✅ [Thread] Berhasil -> Karangan, Trenggalek
# ✅ [Thread] Berhasil -> Pacitan, Pacitan
# ✅ [Thread] Berhasil -> Balung, Jember
# ✅ [Thread] Berhasil -> Tulakan, Pacitan
# ✅ [Thread] Berhasil -> Ngadirojo, Pacitan
# ✅ [Thread] Berhasil -> Pringkuku, Pacitan
# ✅ [Thread] Berhasil -> Durenan, Trenggalek
# ✅ [Thread] Berhasil -> Arjasa, Jember
# ✅ [Thread] Berhasil -> Taman, Sidoarjo
# ✅ [Thread] Berhasil -> Tegalombo, Pacitan
# ✅ [Thread] Berhasil -> Sudimoro, Pacitan
# ✅ [Thread] Berhasil -> Ngantru, Tulungagung
# ✅ [Thread] Berhasil -> Kunjang, Kediri
# ✅ [Thread] Berhasil -> Mojo, Kediri
# ✅ [Thread] Berhasil -> Plosoklaten, Kediri
# ✅ [Thread] Berhasil -> Semen, Kediri
# ✅ [Thread] Berhasil -> Jenggawah, Jember✅ [Thread] Berhasil -> Karangploso, Malang
#
# ✅ [Thread] Berhasil -> Garum, Blitar
# ✅ [Thread] Berhasil -> Wates, Blitar
# ✅ [Thread] Berhasil -> Ringinrejo, Kediri
# ✅ [Thread] Berhasil -> Udanawu, Blitar
# ✅ [Thread] Berhasil -> Panggungrejo, Blitar
# ✅ [Thread] Berhasil -> Ngadiluwih, Kediri
# ✅ [Thread] Berhasil -> Gumukmas, Jember
# ✅ [Thread] Berhasil -> Kras, Kediri
# ✅ [Thread] Berhasil -> Ledokombo, Jember
# ✅ [Thread] Berhasil -> Jelbuk, Jember
# ✅ [Thread] Berhasil -> Pujon, Malang
# ✅ [Thread] Berhasil -> Gondanglegi, Malang
# ✅ [Thread] Berhasil -> Banyakan, Kediri
# ✅ [Thread] Berhasil -> Papar, Kediri
# ✅ [Thread] Berhasil -> Kasembon, Malang
# ✅ [Thread] Berhasil -> Bululawang, Malang
# ✅ [Thread] Berhasil -> Wlingi, Blitar
# ✅ [Thread] Berhasil -> Kalipare, Malang
# ✅ [Thread] Berhasil -> Wonodadi, Blitar
# ✅ [Thread] Berhasil -> Kandangan, Kediri
# ✅ [Thread] Berhasil -> Kencong, Jember
# ✅ [Thread] Berhasil -> Pagak, Malang
# ✅ [Thread] Berhasil -> Puger, Jember
# ✅ [Thread] Berhasil -> Kromengan, Malang
# ✅ [Thread] Berhasil -> Pagelaran, Malang
# ✅ [Thread] Berhasil -> Tajinan, Malang
# ✅ [Thread] Berhasil -> Bangorejo, Banyuwangi
# ✅ [Thread] Berhasil -> Pagu, Kediri
# ✅ [Thread] Berhasil -> Panggul, Trenggalek
# ✅ [Thread] Berhasil -> Ponggok, Blitar
# ✅ [Thread] Berhasil -> Donomulyo, Malang
# ✅ [Thread] Berhasil -> Jabung, Malang
# ✅ [Thread] Berhasil -> Mayang, Jember
# ✅ [Thread] Berhasil -> Kayen Kidul, Kediri
# ✅ [Thread] Berhasil -> Ngasem, Kediri
# ✅ [Thread] Berhasil -> Tarokan, Kediri
# ✅ [Thread] Berhasil -> Ngancar, Kediri
# ✅ [Thread] Berhasil -> Watulimo, Trenggalek
# ✅ [Thread] Berhasil -> Selopuro, Blitar
# ✅ [Thread] Berhasil -> Doko, Blitar
# ✅ [Thread] Berhasil -> Cluring, Banyuwangi
# ✅ [Thread] Berhasil -> Lawang, Malang
# ✅ [Thread] Berhasil -> Kesamben, Blitar
# ✅ [Thread] Berhasil -> Bangsalsari, Jember
# ✅ [Thread] Berhasil -> Pakisaji, Malang
# ✅ [Thread] Berhasil -> Semboro, Jember
# ✅ [Thread] Berhasil -> Sutojayan, Blitar
# ✅ [Thread] Berhasil -> Sumbersari, Jember
# ✅ [Thread] Berhasil -> Donorojo, Pacitan
# ✅ [Thread] Berhasil -> Wates, Kediri
# ✅ [Thread] Berhasil -> Sananankulon, Blitar
# ✅ [Thread] Berhasil -> Kaliwates, Jember
# ✅ [Thread] Berhasil -> Dampit, Malang
# ✅ [Thread] Berhasil -> Arjosari, Pacitan
# ✅ [Thread] Berhasil -> Tempurejo, Jember
# ✅ [Thread] Berhasil -> Singosari, Malang
# ✅ [Thread] Berhasil -> Bantur, Malang
# ✅ [Thread] Berhasil -> Kandat, Kediri
# ✅ [Thread] Berhasil -> Kedungwaru, Tulungagung
# ✅ [Thread] Berhasil -> Campurdarat, Tulungagung
# ✅ [Thread] Berhasil -> Sumbergempol, Tulungagung
# ✅ [Thread] Berhasil -> Karangrejo, Tulungagung
# ✅ [Thread] Berhasil -> Pucanglaban, Tulungagung
# ✅ [Thread] Berhasil -> Boyolangu, Tulungagung
# ✅ [Thread] Berhasil -> Ngunut, Tulungagung
# ✅ [Thread] Berhasil -> Pakel, Tulungagung
# ✅ [Thread] Berhasil -> Kalidawir, Tulungagung
# ✅ [Thread] Berhasil -> Kauman, Tulungagung
# ✅ [Thread] Berhasil -> Sendang, Tulungagung
# ✅ [Thread] Berhasil -> Bandung, Tulungagung
# ✅ [Thread] Berhasil -> Gondang, Tulungagung
# ✅ [Thread] Berhasil -> Besuki, Tulungagung
# ✅ [Thread] Berhasil -> Pagerwojo, Tulungagung
# ✅ [Thread] Berhasil -> Kalibaru, Banyuwangi
# ✅ [Thread] Berhasil -> Sumberbaru, Jember
# ✅ [Thread] Berhasil -> Rambipuji, Jember
# ✅ [Thread] Berhasil -> Sukorambi, Jember
# ✅ [Thread] Berhasil -> Tulungagung, Tulungagung
# ✅ [Thread] Berhasil -> Rogojampi, Banyuwangi
# ✅ [Thread] Berhasil -> Banyuwangi, Banyuwangi
# ✅ [Thread] Berhasil -> Wuluhan, Jember
# ✅ [Thread] Berhasil -> Tanggul, Jember
# ✅ [Thread] Berhasil -> Umbulsari, Jember
# ✅ [Thread] Berhasil -> Silo, Jember
# ✅ [Thread] Berhasil -> Sukowono, Jember
# ✅ [Thread] Berhasil -> Patrang, Jember
# ✅ [Thread] Berhasil -> Tanggunggunung, Tulungagung
# ✅ [Thread] Berhasil -> Rejotangan, Tulungagung
# ✅ [Thread] Berhasil -> Pakusari, Jember
# ✅ [Thread] Berhasil -> Bakung, Blitar
# ✅ [Thread] Berhasil -> Songgon, Banyuwangi
# ✅ [Thread] Berhasil -> Tegaldlimo, Banyuwangi
# ✅ [Thread] Berhasil -> Asembagus, Situbondo
# ✅ [Thread] Berhasil -> Tegalsari, Banyuwangi
# ✅ [Thread] Berhasil -> Arjasa, Situbondo
# ✅ [Thread] Berhasil -> Jatibanteng, Situbondo
# ✅ [Thread] Berhasil -> Binakal, Bondowoso
# ✅ [Thread] Berhasil -> Situbondo, Situbondo
# ✅ [Thread] Berhasil -> Grujugan, Bondowoso
# ✅ [Thread] Berhasil -> Bondowoso, Bondowoso
# ✅ [Thread] Berhasil -> Curahdami, Bondowoso
# ✅ [Thread] Berhasil -> Jambesari Darus Sholah, Bondowoso
# ✅ [Thread] Berhasil -> Licin, Banyuwangi
# ✅ [Thread] Berhasil -> Pakem, Bondowoso
# ✅ [Thread] Berhasil -> Gambiran, Banyuwangi
# ✅ [Thread] Berhasil -> Glagah, Banyuwangi
# ✅ [Thread] Berhasil -> Prajekan, Bondowoso
# ✅ [Thread] Berhasil -> Singojuruh, Banyuwangi
# ✅ [Thread] Berhasil -> Muncar, Banyuwangi
# ✅ [Thread] Berhasil -> Kalipuro, Banyuwangi
# ✅ [Thread] Berhasil -> Kabat, Banyuwangi
# ✅ [Thread] Berhasil -> Pesanggaran, Banyuwangi
# ✅ [Thread] Berhasil -> Purwoharjo, Banyuwangi
# ✅ [Thread] Berhasil -> Sempu, Banyuwangi
# ✅ [Thread] Berhasil -> Giri, Banyuwangi
# ✅ [Thread] Berhasil -> Siliragung, Banyuwangi
# ✅ [Thread] Berhasil -> Glenmore, Banyuwangi
# ✅ [Thread] Berhasil -> Genteng, Banyuwangi
# ✅ [Thread] Berhasil -> Sukosari, Bondowoso
# ✅ [Thread] Berhasil -> Taman Krocok, Bondowoso
# ✅ [Thread] Berhasil -> Banyuglugur, Situbondo
# ✅ [Thread] Berhasil -> Srono, Banyuwangi
# ✅ [Thread] Berhasil -> Mangaran, Situbondo
# ✅ [Thread] Berhasil -> Kendit, Situbondo
# ✅ [Thread] Berhasil -> Sumbermalang, Situbondo
# ✅ [Thread] Berhasil -> Panarukan, Situbondo
# ✅ [Thread] Berhasil -> Besuki, Situbondo
# ✅ [Thread] Berhasil -> Klabang, Bondowoso
# ✅ [Thread] Berhasil -> Kapongan, Situbondo
# ✅ [Thread] Berhasil -> Mlandingan, Situbondo
# ✅ [Thread] Berhasil -> Jangkar, Situbondo
# ✅ [Thread] Berhasil -> Tenggarang, Bondowoso
# ✅ [Thread] Berhasil -> Bungatan, Situbondo
# ✅ [Thread] Berhasil -> Besuk, Probolinggo
# ✅ [Thread] Berhasil -> Cermee, Bondowoso
# ✅ [Thread] Berhasil -> Wongsorejo, Banyuwangi
# ✅ [Thread] Berhasil -> Panji, Situbondo
# ✅ [Thread] Berhasil -> Banyuputih, Situbondo
# ✅ [Thread] Berhasil -> Botolinggo, Bondowoso
# ✅ [Thread] Berhasil -> Suboh, Situbondo
# ✅ [Thread] Berhasil -> Banyuanyar, Probolinggo
# ✅ [Thread] Berhasil -> Maesan, Bondowoso
# ✅ [Thread] Berhasil -> Gending, Probolinggo
# ✅ [Thread] Berhasil -> Krejengan, Probolinggo
# ✅ [Thread] Berhasil -> Krucil, Probolinggo
# ✅ [Thread] Berhasil -> Kraksaan, Probolinggo
# ✅ [Thread] Berhasil -> Kuripan, Probolinggo
# ✅ [Thread] Berhasil -> Maron, Probolinggo
# ✅ [Thread] Berhasil -> Sempol, Bondowoso
# ✅ [Thread] Berhasil -> Sumberwringin, Bondowoso
# ✅ [Thread] Berhasil -> Tapen, Bondowoso
# ✅ [Thread] Berhasil -> Tamanan, Bondowoso
# ✅ [Thread] Berhasil -> Pujer, Bondowoso
# ✅ [Thread] Berhasil -> Tegalampel, Bondowoso
# ✅ [Thread] Berhasil -> Lumbang, Probolinggo
# ✅ [Thread] Berhasil -> Sumber, Probolinggo
# ✅ [Thread] Berhasil -> Wonosari, Bondowoso
# ✅ [Thread] Berhasil -> Kejayan, Pasuruan
# ✅ [Thread] Berhasil -> Kraton, Pasuruan
# ✅ [Thread] Berhasil -> Wringin, Bondowoso
# ✅ [Thread] Berhasil -> Tongas, Probolinggo
# ✅ [Thread] Berhasil -> Dringu, Probolinggo
# ✅ [Thread] Berhasil -> Grati, Pasuruan
# ✅ [Thread] Berhasil -> Pandaan, Pasuruan
# ✅ [Thread] Berhasil -> Gondang Wetan, Pasuruan
# ✅ [Thread] Berhasil -> Tlogosari, Bondowoso
# ✅ [Thread] Berhasil -> Bantaran, Probolinggo
# ✅ [Thread] Berhasil -> Lekok, Pasuruan
# ✅ [Thread] Berhasil -> Sukapura, Probolinggo
# ✅ [Thread] Berhasil -> Gading, Probolinggo
# ✅ [Thread] Berhasil -> Pajarakan, Probolinggo
# ✅ [Thread] Berhasil -> Sukorejo, Pasuruan
# ✅ [Thread] Berhasil -> Leces, Probolinggo
# ✅ [Thread] Berhasil -> Sumberasih, Probolinggo
# ✅ [Thread] Berhasil -> Pakuniran, Probolinggo
# ✅ [Thread] Berhasil -> Kotaanyar, Probolinggo
# ✅ [Thread] Berhasil -> Tiris, Probolinggo
# ✅ [Thread] Berhasil -> Paiton, Probolinggo
# ✅ [Thread] Berhasil -> Nguling, Pasuruan
# ✅ [Thread] Berhasil -> Wonomerto, Probolinggo
# ✅ [Thread] Berhasil -> Tegal Siwalan, Probolinggo
# ✅ [Thread] Berhasil -> Pohjentrek, Pasuruan
# ✅ [Thread] Berhasil -> Prigen, Pasuruan
# ✅ [Thread] Berhasil -> Pasrepan, Pasuruan
# ✅ [Thread] Berhasil -> Beji, Pasuruan
# ✅ [Thread] Berhasil -> Gempol, Pasuruan
# ✅ [Thread] Berhasil -> Lumbang, Pasuruan
# ✅ [Thread] Berhasil -> Bangil, Pasuruan
# ✅ [Thread] Berhasil -> Puspo, Pasuruan
# ✅ [Thread] Berhasil -> Peterongan, Jombang
# ✅ [Thread] Berhasil -> Rejoso, Pasuruan
# ✅ [Thread] Berhasil -> Berbek, Nganjuk
# ✅ [Thread] Berhasil -> Winongan, Pasuruan
# ✅ [Thread] Berhasil -> Tosari, Pasuruan
# ✅ [Thread] Berhasil -> Gudo, Jombang
# ✅ [Thread] Berhasil -> Sumobito, Jombang
# ✅ [Thread] Berhasil -> Cukir, Jombang
# ✅ [Thread] Berhasil -> Ngusikan, Jombang
# ✅ [Thread] Berhasil -> Wonosari, Pasuruan
# ✅ [Thread] Berhasil -> Bandar Kedung Mulyo, Jombang
# ✅ [Thread] Berhasil -> Jombang, Jombang
# ✅ [Thread] Berhasil -> Diwek, Jombang
# ✅ [Thread] Berhasil -> Purwodadi, Pasuruan
# ✅ [Thread] Berhasil -> Tutur, Pasuruan
# ✅ [Thread] Berhasil -> Bareng, Jombang
# ✅ [Thread] Berhasil -> Purwosari, Pasuruan
# ✅ [Thread] Berhasil -> Rembang, Pasuruan
# ✅ [Thread] Berhasil -> Ngambon, Bojonegoro
# ✅ [Thread] Berhasil -> Lengkong, Nganjuk
# ✅ [Thread] Berhasil -> Gondang, Nganjuk
# ✅ [Thread] Berhasil -> Dander, Bojonegoro
# ✅ [Thread] Berhasil -> Kembangbahu, Lamongan
# ✅ [Thread] Berhasil -> Ngluyu, Nganjuk
# ✅ [Thread] Berhasil -> Kabuh, Jombang
# ✅ [Thread] Berhasil -> Ngoro, Jombang
# ✅ [Thread] Berhasil -> Kudu, Jombang
# ✅ [Thread] Berhasil -> Padangan, Bojonegoro
# ✅ [Thread] Berhasil -> Rejoso, Nganjuk
# ✅ [Thread] Berhasil -> Baron, Nganjuk
# ✅ [Thread] Berhasil -> Balen, Bojonegoro
# ✅ [Thread] Berhasil -> Ngetos, Nganjuk
# ✅ [Thread] Berhasil -> Bojonegoro, Bojonegoro
# ✅ [Thread] Berhasil -> Bagor, Nganjuk
# ✅ [Thread] Berhasil -> Jogoroto, Jombang
# ✅ [Thread] Berhasil -> Modo, Lamongan
# ✅ [Thread] Berhasil -> Loceret, Nganjuk
# ✅ [Thread] Berhasil -> Perak, Jombang
# ✅ [Thread] Berhasil -> Mojoagung, Jombang
# ✅ [Thread] Berhasil -> Gondang, Bojonegoro
# ✅ [Thread] Berhasil -> Deket, Lamongan
# ✅ [Thread] Berhasil -> Karangbinangun, Lamongan
# ✅ [Thread] Berhasil -> Ploso, Jombang
# ✅ [Thread] Berhasil -> Mojowarno, Jombang
# ✅ [Thread] Berhasil -> Kesamben, Jombang
# ✅ [Thread] Berhasil -> Plandaan, Jombang
# ✅ [Thread] Berhasil -> Sumberrejo, Bojonegoro
# ✅ [Thread] Berhasil -> Sawahan, Nganjuk
# ✅ [Thread] Berhasil -> Megaluh, Jombang
# ✅ [Thread] Berhasil -> Tembelang, Jombang
# ✅ [Thread] Berhasil -> Sekaran, Lamongan
# ✅ [Thread] Berhasil -> Kertosono, Nganjuk
# ✅ [Thread] Berhasil -> Jatikalen, Nganjuk
# ✅ [Thread] Berhasil -> Kepohbaru, Bojonegoro
# ✅ [Thread] Berhasil -> Temayang, Bojonegoro
# ✅ [Thread] Berhasil -> Ngimbang, Lamongan
# ✅ [Thread] Berhasil -> Kasiman, Bojonegoro
# ✅ [Thread] Berhasil -> Kapas, Bojonegoro
# ✅ [Thread] Berhasil -> Ngasem, Bojonegoro
# ✅ [Thread] Berhasil -> Bubulan, Bojonegoro
# ✅ [Thread] Berhasil -> Sukomoro, Nganjuk
# ✅ [Thread] Berhasil -> Patianrowo, Nganjuk
# ✅ [Thread] Berhasil -> Kalitengah, Lamongan
# ✅ [Thread] Berhasil -> Glagah, Lamongan
# ✅ [Thread] Berhasil -> Trucuk, Bojonegoro
# ✅ [Thread] Berhasil -> Sugihwaras, Bojonegoro
# ✅ [Thread] Berhasil -> Nganjuk, Nganjuk
# ✅ [Thread] Berhasil -> Pace, Nganjuk
# ✅ [Thread] Berhasil -> Malo, Bojonegoro
# ✅ [Thread] Berhasil -> Kadewan, Bojonegoro
# ✅ [Thread] Berhasil -> Ngraho, Bojonegoro
# ✅ [Thread] Berhasil -> Paciran, Lamongan
# ✅ [Thread] Berhasil -> Prambon, Nganjuk
# ✅ [Thread] Berhasil -> Kedungpring, Lamongan
# ✅ [Thread] Berhasil -> Purwosari, Bojonegoro
# ✅ [Thread] Berhasil -> Lamongan, Lamongan
# ✅ [Thread] Berhasil -> Sarirejo, Lamongan
# ✅ [Thread] Berhasil -> Sukosewu, Bojonegoro
# ✅ [Thread] Berhasil -> Margomulyo, Bojonegoro
# ✅ [Thread] Berhasil -> Tambakrejo, Bojonegoro
# ✅ [Thread] Berhasil -> Brondong, Lamongan
# ✅ [Thread] Berhasil -> Kedungadem, Bojonegoro
# ✅ [Thread] Berhasil -> Sambeng, Lamongan
# ✅ [Thread] Berhasil -> Ngronggot, Nganjuk
# ✅ [Thread] Berhasil -> Sekar, Bojonegoro
# ✅ [Thread] Berhasil -> Maduran, Lamongan
# ✅ [Thread] Berhasil -> Mantup, Lamongan
# ✅ [Thread] Berhasil -> Kalitidu, Bojonegoro
# ✅ [Thread] Berhasil -> Baureno, Bojonegoro
# ✅ [Thread] Berhasil -> Babat, Lamongan
# ✅ [Thread] Berhasil -> Tanjunganom, Nganjuk
# ✅ [Thread] Berhasil -> Bluluk, Lamongan
# ✅ [Thread] Berhasil -> Gayam, Bojonegoro
# ✅ [Thread] Berhasil -> Laren, Lamongan
# ✅ [Thread] Berhasil -> Montong, Tuban
# ✅ [Thread] Berhasil -> Wilangan, Nganjuk
# ✅ [Thread] Berhasil -> Jatirogo, Tuban
# ✅ [Thread] Berhasil -> Pucuk, Lamongan
# ✅ [Thread] Berhasil -> Palang, Tuban
# ✅ [Thread] Berhasil -> Karanggeneng, Lamongan
# ✅ [Thread] Berhasil -> Plumpang, Tuban
# ✅ [Thread] Berhasil -> Tanjungbumi, Bangkalan
# ✅ [Thread] Berhasil -> Ajung, Jember
# ✅ [Thread] Berhasil -> Widang, Tuban
# ✅ [Thread] Berhasil -> Tanah Merah, Bangkalan
# ✅ [Thread] Berhasil -> Menganti, Gresik
# ✅ [Thread] Berhasil -> Tambak, Gresik
# ✅ [Thread] Berhasil -> Jenu, Tuban
# ✅ [Thread] Berhasil -> Bangkalan, Bangkalan
# ✅ [Thread] Berhasil -> Banyuates, Sampang
# ✅ [Thread] Berhasil -> Tragah, Bangkalan
# ✅ [Thread] Berhasil -> Kenduruan, Tuban
# ✅ [Thread] Berhasil -> Modung, Bangkalan
# ✅ [Thread] Berhasil -> Bangilan, Tuban
# ✅ [Thread] Berhasil -> Cerme, Gresik
# ✅ [Thread] Berhasil -> Kebomas, Gresik
# ✅ [Thread] Berhasil -> Turi, Lamongan
# ✅ [Thread] Berhasil -> Solokuro, Lamongan
# ✅ [Thread] Berhasil -> Sukodadi, Lamongan
# ✅ [Thread] Berhasil -> Tikung, Lamongan
# ✅ [Thread] Berhasil -> Merakurak, Tuban
# ✅ [Thread] Berhasil -> Sumberpucung, Malang
# ✅ [Thread] Berhasil -> Parengan, Tuban
# ✅ [Thread] Berhasil -> Manyar, Gresik
# ✅ [Thread] Berhasil -> Sukorame, Lamongan
# ✅ [Thread] Berhasil -> Tirtoyudo, Malang
# ✅ [Thread] Berhasil -> Sugio, Lamongan
# ✅ [Thread] Berhasil -> Karang Penang, Sampang
# ✅ [Thread] Berhasil -> Kokop, Bangkalan
# ✅ [Thread] Berhasil -> Kerek, Tuban
# ✅ [Thread] Berhasil -> Bancar, Tuban
# ✅ [Thread] Berhasil -> Batuan, Sumenep
# ✅ [Thread] Berhasil -> Jrengik, Sampang
# ✅ [Thread] Berhasil -> Arosbaya, Bangkalan
# ✅ [Thread] Berhasil -> Geger, Bangkalan
# ✅ [Thread] Berhasil -> Panceng, Gresik
# ✅ [Thread] Berhasil -> Burneh, Bangkalan
# ✅ [Thread] Berhasil -> Ujung Pangkah, Gresik
# ✅ [Thread] Berhasil -> Turen, Malang
# ✅ [Thread] Berhasil -> Tumpang, Malang
# ✅ [Thread] Berhasil -> Balongpanggang, Gresik
# ✅ [Thread] Berhasil -> Benjeng, Gresik
# ✅ [Thread] Berhasil -> Wagir, Malang
# ✅ [Thread] Berhasil -> Gresik, Gresik
# ✅ [Thread] Berhasil -> Bungah, Gresik
# ✅ [Thread] Berhasil -> Semanding, Tuban
# ✅ [Thread] Berhasil -> Singgahan, Tuban
# ✅ [Thread] Berhasil -> Socah, Bangkalan
# ✅ [Thread] Berhasil -> Senori, Tuban
# ✅ [Thread] Berhasil -> Tambakboyo, Tuban
# ✅ [Thread] Berhasil -> Klampis, Bangkalan
# ✅ [Thread] Berhasil -> Duduk Sampeyan, Gresik
# ✅ [Thread] Berhasil -> Driyorejo, Gresik
# ✅ [Thread] Berhasil -> Soko, Tuban
# ✅ [Thread] Berhasil -> Sepulu, Bangkalan
# ✅ [Thread] Berhasil -> Sidayu, Gresik
# ✅ [Thread] Berhasil -> Wringinanom, Gresik
# ✅ [Thread] Berhasil -> Dukun, Gresik
# ✅ [Thread] Berhasil -> Wajak, Malang
# ✅ [Thread] Berhasil -> Grabagan, Tuban
# ✅ [Thread] Berhasil -> Kedamean, Gresik
# ✅ [Thread] Berhasil -> Blega, Bangkalan
# ✅ [Thread] Berhasil -> Tambelangan, Sampang
# ✅ [Thread] Berhasil -> Tuban, Tuban
# ✅ [Thread] Berhasil -> Rengel, Tuban
# ✅ [Thread] Berhasil -> Omben, Sampang
# ✅ [Thread] Berhasil -> Galis, Bangkalan
# ✅ [Thread] Berhasil -> Camplong, Sampang
# ✅ [Thread] Berhasil -> Kamal, Bangkalan
# ✅ [Thread] Berhasil -> Sampang, Sampang
# ✅ [Thread] Berhasil -> Kedungdung, Sampang
# ✅ [Thread] Berhasil -> Waru, Pamekasan
# ✅ [Thread] Berhasil -> Kalianget, Sumenep
# ✅ [Thread] Berhasil -> Pangarengan, Sampang
# ✅ [Thread] Berhasil -> Mojoanyar, Mojokerto
# ✅ [Thread] Berhasil -> Batuputih, Sumenep
# ✅ [Thread] Berhasil -> Talango, Sumenep
# ✅ [Thread] Berhasil -> Sapeken, Sumenep
# ✅ [Thread] Berhasil -> Ketapang, Sampang
# ✅ [Thread] Berhasil -> Sreseh, Sampang
# ✅ [Thread] Berhasil -> Robatal, Sampang
# ✅ [Thread] Berhasil -> Torjun, Sampang
# ✅ [Thread] Berhasil -> Sokobanah, Sampang
# ✅ [Thread] Berhasil -> Pademawu, Pamekasan
# ✅ [Thread] Berhasil -> Jatirejo, Mojokerto
# ✅ [Thread] Berhasil -> Kota Sumenep, Sumenep
# ✅ [Thread] Berhasil -> Bluto, Sumenep
# ✅ [Thread] Berhasil -> Dasuk, Sumenep
# ✅ [Thread] Berhasil -> Larangan, Pamekasan
# ✅ [Thread] Berhasil -> Dungkek, Sumenep
# ✅ [Thread] Berhasil -> Batumarmar, Pamekasan
# ✅ [Thread] Berhasil -> Proppo, Pamekasan
# ✅ [Thread] Berhasil -> Trawas, Mojokerto
# ✅ [Thread] Berhasil -> Sooko, Mojokerto
# ✅ [Thread] Berhasil -> Pegantenan, Pamekasan
# ✅ [Thread] Berhasil -> Bumiaji, Batu
# ✅ [Thread] Berhasil -> Junrejo, Batu
# ✅ [Thread] Berhasil -> Kutorejo, Mojokerto
# ✅ [Thread] Berhasil -> Bangsal, Mojokerto
# ✅ [Thread] Berhasil -> Pragaan, Sumenep
# ✅ [Thread] Berhasil -> Kadur, Pamekasan
# ✅ [Thread] Berhasil -> Ganding, Sumenep
# ✅ [Thread] Berhasil -> Pasongsongan, Sumenep
# ✅ [Thread] Berhasil -> Kemlagi, Mojokerto
# ✅ [Thread] Berhasil -> Pamekasan, Pamekasan
# ✅ [Thread] Berhasil -> Ra'as, Sumenep
# ✅ [Thread] Berhasil -> Giliginting, Sumenep
# ✅ [Thread] Berhasil -> Dlanggu, Mojokerto
# ✅ [Thread] Berhasil -> Puri, Mojokerto
# ✅ [Thread] Berhasil -> Gayam, Sumenep
# ✅ [Thread] Berhasil -> Gondang, Mojokerto
# ✅ [Thread] Berhasil -> Saronggi, Sumenep
# ✅ [Thread] Berhasil -> Masalembu, Sumenep
# ✅ [Thread] Berhasil -> Gubeng, Surabaya
# ✅ [Thread] Berhasil -> Pasean, Pamekasan
# ✅ [Thread] Berhasil -> Klojen, Malang
# ✅ [Thread] Berhasil -> Jetis, Mojokerto
# ✅ [Thread] Berhasil -> Batu, Batu
# ✅ [Thread] Berhasil -> Trowulan, Mojokerto
# ✅ [Thread] Berhasil -> Ngoro, Mojokerto
# ✅ [Thread] Berhasil -> Palenggaan, Pamekasan
# ✅ [Thread] Berhasil -> Kedungkandang, Malang
# ✅ [Thread] Berhasil -> Dawarblandong, Mojokerto
# ✅ [Thread] Berhasil -> Guluk-Guluk, Sumenep
# ✅ [Thread] Berhasil -> Lowokwaru, Malang
# ✅ [Thread] Berhasil -> Rubaru, Sumenep
# ✅ [Thread] Berhasil -> Pacet, Mojokerto
# ✅ [Thread] Berhasil -> Arjasa, Sumenep
# ✅ [Thread] Berhasil -> Lenteng, Sumenep
# ✅ [Thread] Berhasil -> Pakong, Pamekasan
# ✅ [Thread] Berhasil -> Galis, Pamekasan
# ✅ [Thread] Berhasil -> Kota Kediri, Kediri
# ✅ [Thread] Berhasil -> Gedeg, Mojokerto
# ✅ [Thread] Berhasil -> Nonggunong, Sumenep
# ✅ [Thread] Berhasil -> Manding, Sumenep
# ✅ [Thread] Berhasil -> Sukorejo, Blitar
# ✅ [Thread] Berhasil -> Kepanjenkidul, Blitar
# ✅ [Thread] Berhasil -> Blimbing, Malang
# ✅ [Thread] Berhasil -> Mojosari, Mojokerto
# ✅ [Thread] Berhasil -> Kangayan, Sumenep
# ✅ [Thread] Berhasil -> Batang Batang, Sumenep
# ✅ [Thread] Berhasil -> Gapura, Sumenep
# ✅ [Thread] Berhasil -> Ambunten, Sumenep
# ✅ [Thread] Berhasil -> Pungging, Mojokerto
# ✅ [Thread] Berhasil -> Tlanakan, Pamekasan
# ✅ [Thread] Berhasil -> Magersari, Mojokerto
# ✅ [Thread] Berhasil -> Kanigaran, Probolinggo
# ✅ [Thread] Berhasil -> Mojoroto, Kediri
# ✅ [Thread] Berhasil -> Sananwetan, Blitar
# ✅ [Thread] Berhasil -> Sukun, Malang
# ✅ [Thread] Berhasil -> Gadingrejo, Pasuruan
# ✅ [Thread] Berhasil -> Pesantren, Kediri
# ✅ [Thread] Berhasil -> Wonoasih, Probolinggo
# ✅ [Thread] Berhasil -> Mayangan, Probolinggo
# ✅ [Thread] Berhasil -> Karangpilang, Surabaya
# ✅ [Thread] Berhasil -> Kedopok, Probolinggo
# ✅ [Thread] Berhasil -> Purworejo, Pasuruan
# ✅ [Thread] Berhasil -> Bugul Kidul, Pasuruan
# ✅ [Thread] Berhasil -> Prajurit Kulon, Mojokerto
# ✅ [Thread] Berhasil -> Manguharjo, Madiun
# ✅ [Thread] Berhasil -> Taman, Madiun
# ✅ [Thread] Berhasil -> Panggungrejo, Pasuruan
# ✅ [Thread] Berhasil -> Kartoharjo, Madiun
# ✅ [Thread] Berhasil -> Kademangan, Probolinggo
# ✅ [Thread] Berhasil -> Konang, Bangkalan
# ✅ [Thread] Berhasil -> Kwanyar, Bangkalan
# ✅ [Thread] Berhasil -> Sangkapura, Gresik
# ✅ [Thread] Berhasil -> Labang, Bangkalan
#
# Semua thread selesai. Menulis data ke Excel...
#
# ✅ Selesai! Data cuaca telah ditulis ke 'DaftarKecamatan_kelompok_6.xlsx'.
# Total waktu eksekusi (Multi-Thread): 0:00:04.315768
